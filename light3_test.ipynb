# %%
import tensorflow as tf
# Out:
# 2023-11-22 14:20:14.717414: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-22 14:20:14.717468: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-22 14:20:14.718515: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-11-22 14:20:14.815150: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-11-22 14:20:15.937789: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
tf.config.list_physical_devices("GPU")
# Out:
# 2023-11-22 14:20:17.275043: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-22 14:20:17.445482: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-22 14:20:17.445781: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
import cv2
from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.applications.vgg16 import preprocess_input, decode_predictions
import random
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline

# %%
import os
path = "./light_on_off/"
os.listdir(path)
# Out:
# ['lightOFF.240.jpg',
#  'lightOFF.530.jpg',
#  'lightON.1073.jpg',
#  'lightON.852.jpg',
#  'lightOFF.80.jpg',
#  'lightON.34.jpg',
#  'lightOFF.576.jpg',
#  'lightON.759.jpg',
#  'lightOFF.184.jpg',
#  'lightOFF.208.jpg',
#  'lightON.236.jpg',
#  'lightOFF.83.jpg',
#  'lightON.474.jpg',
#  'lightOFF.42.jpg',
#  'lightON.999.jpg',
#  'lightON.293.jpg',
#  'lightOFF.448.jpg',
#  'lightON.496.jpg',
#  'lightOFF.726.jpg',
#  'lightOFF.949.jpg',
#  'lightOFF.56.jpg',
#  'lightOFF.882.jpg',
#  'lightOFF.101.jpg',
#  'lightON.52.jpg',
#  'lightOFF.675.jpg',
#  'lightOFF.828.jpg',
#  'lightON.741.jpg',
#  'lightOFF.581.jpg',
#  'lightOFF.85.jpg',
#  'lightON.562.jpg',
#  'lightOFF.99.jpg',
#  'lightON.176.jpg',
#  'lightOFF.251.jpg',
#  'lightON.771.jpg',
#  'lightON.584.jpg',
#  'lightOFF.142.jpg',
#  'lightOFF.491.jpg',
#  'lightON.102.jpg',
#  'lightOFF.671.jpg',
#  'lightON.169.jpg',
#  'lightOFF.421.jpg',
#  'lightOFF.592.jpg',
#  'lightOFF.452.jpg',
#  'lightON.790.jpg',
#  'lightON.207.jpg',
#  'lightOFF.925.jpg',
#  'lightON.794.jpg',
#  'lightON.954.jpg',
#  'lightON.1068.jpg',
#  'lightON.38.jpg',
#  'lightON.887.jpg',
#  'lightOFF.608.jpg',
#  'lightON.42.jpg',
#  'lightOFF.688.jpg',
#  'lightON.784.jpg',
#  'lightOFF.103.jpg',
#  'lightON.626.jpg',
#  'lightON.509.jpg',
#  'lightON.811.jpg',
#  'lightON.537.jpg',
#  'lightON.419.jpg',
#  'lightOFF.713.jpg',
#  'lightOFF.838.jpg',
#  'lightOFF.690.jpg',
#  'lightON.343.jpg',
#  'lightON.417.jpg',
#  'lightOFF.432.jpg',
#  'lightOFF.317.jpg',
#  'lightON.484.jpg',
#  'lightOFF.556.jpg',
#  'lightON.640.jpg',
#  'lightON.54.jpg',
#  'lightON.392.jpg',
#  'lightON.374.jpg',
#  'lightOFF.52.jpg',
#  'lightON.662.jpg',
#  'lightOFF.944.jpg',
#  'lightOFF.7.jpg',
#  'lightOFF.417.jpg',
#  'lightOFF.89.jpg',
#  'lightON.194.jpg',
#  'lightOFF.538.jpg',
#  'lightON.793.jpg',
#  'lightOFF.201.jpg',
#  'lightOFF.1010.jpg',
#  'lightON.160.jpg',
#  'lightON.695.jpg',
#  'lightON.83.jpg',
#  'lightON.565.jpg',
#  'lightOFF.967.jpg',
#  'lightON.30.jpg',
#  'lightOFF.265.jpg',
#  'lightON.1012.jpg',
#  'lightON.832.jpg',
#  'lightON.991.jpg',
#  'lightON.10.jpg',
#  'lightOFF.705.jpg',
#  'lightOFF.914.jpg',
#  'lightOFF.250.jpg',
#  'lightON.1014.jpg',
#  'lightON.351.jpg',
#  'lightON.446.jpg',
#  'lightON.1091.jpg',
#  'lightON.279.jpg',
#  'lightON.55.jpg',
#  'lightON.386.jpg',
#  'lightON.384.jpg',
#  'lightOFF.565.jpg',
#  'lightON.468.jpg',
#  'lightON.842.jpg',
#  'lightON.1127.jpg',
#  'lightOFF.864.jpg',
#  'lightOFF.869.jpg',
#  'lightON.25.jpg',
#  'lightOFF.333.jpg',
#  'lightOFF.693.jpg',
#  'lightOFF.638.jpg',
#  'lightOFF.461.jpg',
#  'lightOFF.200.jpg',
#  'lightOFF.426.jpg',
#  'lightON.804.jpg',
#  'lightOFF.267.jpg',
#  'lightON.322.jpg',
#  'lightOFF.1.jpg',
#  'lightON.165.jpg',
#  'lightOFF.82.jpg',
#  'lightOFF.810.jpg',
#  'lightOFF.964.jpg',
#  'lightOFF.279.jpg',
#  'lightOFF.8.jpg',
#  'lightOFF.1024.jpg',
#  'lightON.444.jpg',
#  'lightON.588.jpg',
#  'lightON.1010.jpg',
#  'lightON.700.jpg',
#  'lightON.965.jpg',
#  'lightON.963.jpg',
#  'lightOFF.978.jpg',
#  'lightON.659.jpg',
#  'lightOFF.783.jpg',
#  'lightOFF.812.jpg',
#  'lightOFF.413.jpg',
#  'lightOFF.769.jpg',
#  'lightON.731.jpg',
#  'lightOFF.972.jpg',
#  'lightOFF.408.jpg',
#  'lightOFF.15.jpg',
#  'lightON.341.jpg',
#  'lightON.639.jpg',
#  'lightON.625.jpg',
#  'lightON.872.jpg',
#  'lightOFF.108.jpg',
#  'lightON.72.jpg',
#  'lightOFF.494.jpg',
#  'lightOFF.682.jpg',
#  'lightON.378.jpg',
#  'lightON.1135.jpg',
#  'lightOFF.583.jpg',
#  'lightON.838.jpg',
#  'lightON.87.jpg',
#  'lightON.460.jpg',
#  'lightOFF.79.jpg',
#  'lightON.1032.jpg',
#  'lightOFF.346.jpg',
#  'lightOFF.357.jpg',
#  'lightON.777.jpg',
#  'lightON.317.jpg',
#  'lightOFF.1001.jpg',
#  'lightON.660.jpg',
#  'lightOFF.13.jpg',
#  'lightON.1085.jpg',
#  'lightOFF.442.jpg',
#  'lightON.77.jpg',
#  'lightOFF.593.jpg',
#  'lightOFF.364.jpg',
#  'lightON.492.jpg',
#  'lightOFF.243.jpg',
#  'lightOFF.167.jpg',
#  'lightON.459.jpg',
#  'lightON.712.jpg',
#  'lightOFF.383.jpg',
#  'lightON.155.jpg',
#  'lightOFF.821.jpg',
#  'lightON.523.jpg',
#  'lightON.827.jpg',
#  'lightON.686.jpg',
#  'lightON.106.jpg',
#  'lightON.555.jpg',
#  'lightOFF.798.jpg',
#  'lightON.573.jpg',
#  'lightOFF.248.jpg',
#  'lightON.438.jpg',
#  'lightOFF.482.jpg',
#  'lightON.947.jpg',
#  'lightON.355.jpg',
#  'lightON.321.jpg',
#  'lightOFF.786.jpg',
#  'lightOFF.110.jpg',
#  'lightOFF.382.jpg',
#  'lightOFF.803.jpg',
#  'lightOFF.519.jpg',
#  'lightON.393.jpg',
#  'lightON.685.jpg',
#  'lightON.633.jpg',
#  'lightOFF.336.jpg',
#  'lightOFF.5.jpg',
#  'lightOFF.77.jpg',
#  'lightON.243.jpg',
#  'lightON.383.jpg',
#  'lightON.591.jpg',
#  'lightOFF.270.jpg',
#  'lightOFF.450.jpg',
#  'lightON.486.jpg',
#  'lightON.190.jpg',
#  'lightON.218.jpg',
#  'lightOFF.349.jpg',
#  'lightOFF.74.jpg',
#  'lightOFF.956.jpg',
#  'lightON.1117.jpg',
#  'lightOFF.680.jpg',
#  'lightOFF.1012.jpg',
#  'lightON.781.jpg',
#  'lightOFF.857.jpg',
#  'lightON.944.jpg',
#  'lightON.111.jpg',
#  'lightOFF.55.jpg',
#  'lightOFF.136.jpg',
#  'lightON.524.jpg',
#  'lightON.959.jpg',
#  'lightOFF.479.jpg',
#  'lightOFF.459.jpg',
#  'lightON.27.jpg',
#  'lightOFF.525.jpg',
#  'lightON.94.jpg',
#  'lightOFF.281.jpg',
#  'lightON.300.jpg',
#  'lightOFF.535.jpg',
#  'lightON.104.jpg',
#  'lightOFF.930.jpg',
#  'lightON.1000.jpg',
#  'lightON.679.jpg',
#  'lightON.149.jpg',
#  'lightON.1037.jpg',
#  'lightOFF.990.jpg',
#  'lightOFF.900.jpg',
#  'lightON.191.jpg',
#  'lightON.657.jpg',
#  'lightON.919.jpg',
#  'lightON.311.jpg',
#  'lightON.923.jpg',
#  'lightON.359.jpg',
#  'lightON.112.jpg',
#  'lightON.527.jpg',
#  'lightON.41.jpg',
#  'lightON.369.jpg',
#  'lightOFF.356.jpg',
#  'lightOFF.588.jpg',
#  'lightOFF.495.jpg',
#  'lightON.1044.jpg',
#  'lightON.244.jpg',
#  'lightOFF.307.jpg',
#  'lightOFF.1322.jpg',
#  'lightON.514.jpg',
#  'lightOFF.183.jpg',
#  'lightOFF.473.jpg',
#  'lightON.815.jpg',
#  'lightON.921.jpg',
#  'lightON.845.jpg',
#  'lightOFF.721.jpg',
#  'lightON.239.jpg',
#  'lightON.18.jpg',
#  'lightOFF.957.jpg',
#  'lightOFF.402.jpg',
#  'lightON.1060.jpg',
#  'lightON.730.jpg',
#  'lightON.683.jpg',
#  'lightOFF.191.jpg',
#  'lightON.843.jpg',
#  'lightOFF.963.jpg',
#  'lightOFF.722.jpg',
#  'lightON.206.jpg',
#  'lightOFF.825.jpg',
#  'lightOFF.329.jpg',
#  'lightON.895.jpg',
#  'lightON.718.jpg',
#  'lightON.172.jpg',
#  'lightON.434.jpg',
#  'lightON.652.jpg',
#  'lightON.593.jpg',
#  'lightOFF.43.png',
#  'lightOFF.911.jpg',
#  'lightON.32.jpg',
#  'lightOFF.164.jpg',
#  'lightOFF.773.jpg',
#  'lightON.199.jpg',
#  'lightON.810.jpg',
#  'lightON.851.jpg',
#  'lightON.549.jpg',
#  'lightON.544.jpg',
#  'lightON.431.jpg',
#  'lightOFF.920.jpg',
#  'lightOFF.443.jpg',
#  'lightOFF.470.jpg',
#  'lightON.440.jpg',
#  'lightON.993.jpg',
#  'lightON.566.jpg',
#  'lightOFF.68.jpg',
#  'lightOFF.901.jpg',
#  'lightOFF.529.jpg',
#  'lightON.580.jpg',
#  'lightOFF.406.jpg',
#  'lightON.671.jpg',
#  'lightON.994.jpg',
#  'lightON.502.jpg',
#  'lightOFF.958.jpg',
#  'lightON.450.jpg',
#  'lightOFF.689.jpg',
#  'lightON.449.jpg',
#  'lightON.242.jpg',
#  'lightOFF.521.jpg',
#  'lightOFF.1002.jpg',
#  'lightOFF.766.jpg',
#  'lightOFF.740.jpg',
#  'lightOFF.385.jpg',
#  'lightON.614.jpg',
#  'lightON.382.jpg',
#  'lightOFF.244.jpg',
#  'lightOFF.489.jpg',
#  'lightON.972.jpg',
#  'lightOFF.1016.jpg',
#  'lightOFF.723.jpg',
#  'lightON.682.jpg',
#  'lightOFF.20.jpg',
#  'lightOFF.739.jpg',
#  'lightOFF.398.jpg',
#  'lightOFF.431.jpg',
#  'lightON.807.jpg',
#  'lightON.592.jpg',
#  'lightON.1084.jpg',
#  'lightON.137.jpg',
#  'lightOFF.587.jpg',
#  'lightON.1.jpg',
#  'lightOFF.86.jpg',
#  'lightON.148.jpg',
#  'lightON.1131.jpg',
#  'lightOFF.198.jpg',
#  'lightOFF.405.jpg',
#  'lightON.648.jpg',
#  'lightOFF.1007.jpg',
#  'lightON.916.jpg',
#  'lightON.1111.jpg',
#  'lightOFF.1027.jpg',
#  'lightOFF.61.jpg',
#  'lightOFF.194.jpg',
#  'lightOFF.509.jpg',
#  'lightOFF.221.jpg',
#  'lightOFF.574.jpg',
#  'lightON.326.jpg',
#  'lightON.11.jpg',
#  'lightOFF.363.jpg',
#  'lightOFF.523.jpg',
#  'lightOFF.203.jpg',
#  'lightON.338.jpg',
#  'lightON.39.jpg',
#  'lightON.162.jpg',
#  'lightOFF.510.jpg',
#  'lightOFF.585.jpg',
#  'lightON.498.jpg',
#  'lightOFF.165.jpg',
#  'lightOFF.756.jpg',
#  'lightON.433.jpg',
#  'lightON.687.jpg',
#  'lightON.428.jpg',
#  'lightOFF.330.jpg',
#  'lightOFF.381.jpg',
#  'lightON.118.jpg',
#  'lightON.396.jpg',
#  'lightOFF.845.jpg',
#  'lightOFF.937.jpg',
#  'lightOFF.707.jpg',
#  'lightOFF.69.jpg',
#  'lightON.603.jpg',
#  'lightOFF.843.jpg',
#  'lightOFF.544.jpg',
#  'lightOFF.399.jpg',
#  'lightON.520.jpg',
#  'lightON.518.jpg',
#  'lightON.362.jpg',
#  'lightON.129.jpg',
#  'lightON.904.jpg',
#  'lightON.707.jpg',
#  'lightON.945.jpg',
#  'lightON.911.jpg',
#  'lightON.831.jpg',
#  'lightOFF.657.jpg',
#  'lightON.724.jpg',
#  'lightON.1022.jpg',
#  'lightOFF.935.jpg',
#  'lightOFF.124.jpg',
#  'lightOFF.806.jpg',
#  'lightON.788.jpg',
#  'lightOFF.2.jpg',
#  'lightON.909.jpg',
#  'lightOFF.787.jpg',
#  'lightOFF.280.jpg',
#  'lightOFF.634.jpg',
#  'lightON.1094.jpg',
#  'lightON.57.jpg',
#  'lightON.51.jpg',
#  'lightON.619.jpg',
#  'lightON.262.jpg',
#  'lightON.327.jpg',
#  'lightON.451.jpg',
#  'lightON.435.jpg',
#  'lightON.114.jpg',
#  'lightON.705.jpg',
#  'lightOFF.868.jpg',
#  'lightON.1036.jpg',
#  'lightON.423.jpg',
#  'lightON.688.jpg',
#  'lightOFF.577.jpg',
#  'lightOFF.560.jpg',
#  'lightOFF.975.jpg',
#  'lightON.869.jpg',
#  'lightON.914.jpg',
#  'lightON.697.jpg',
#  'lightON.927.jpg',
#  'lightON.884.jpg',
#  'lightON.346.jpg',
#  'lightON.213.jpg',
#  'lightOFF.496.jpg',
#  'lightOFF.420.jpg',
#  'lightOFF.970.jpg',
#  'lightON.1125.jpg',
#  'lightOFF.738.jpg',
#  'lightON.577.jpg',
#  'lightOFF.44.png',
#  'lightON.635.jpg',
#  'lightON.250.jpg',
#  'lightOFF.989.jpg',
#  'lightON.974.jpg',
#  'lightON.254.jpg',
#  'lightOFF.70.jpg',
#  'lightON.71.jpg',
#  'lightON.1027.jpg',
#  'lightON.881.jpg',
#  'lightON.475.jpg',
#  'lightON.888.jpg',
#  'lightOFF.199.jpg',
#  'lightOFF.751.jpg',
#  'lightON.825.jpg',
#  'lightOFF.348.jpg',
#  'lightOFF.63.jpg',
#  'lightON.567.jpg',
#  'lightOFF.516.jpg',
#  'lightOFF.784.jpg',
#  'lightOFF.663.jpg',
#  'lightOFF.295.jpg',
#  'lightON.670.jpg',
#  'lightON.553.jpg',
#  'lightOFF.916.jpg',
#  'lightON.1116.jpg',
#  'lightOFF.196.jpg',
#  'lightOFF.301.jpg',
#  'lightOFF.517.jpg',
#  'lightOFF.418.jpg',
#  'lightON.196.jpg',
#  'lightOFF.932.jpg',
#  'lightON.906.jpg',
#  'lightOFF.45.jpg',
#  'lightOFF.154.jpg',
#  'lightON.437.jpg',
#  'lightOFF.484.jpg',
#  'lightON.694.jpg',
#  'lightOFF.758.jpg',
#  'lightON.728.jpg',
#  'lightON.860.jpg',
#  'lightOFF.570.jpg',
#  'lightON.1109.jpg',
#  'lightON.495.jpg',
#  'lightOFF.762.jpg',
#  'lightON.561.jpg',
#  'lightON.511.jpg',
#  'lightOFF.38.jpg',
#  'lightON.1061.jpg',
#  'lightOFF.258.jpg',
#  'lightON.388.jpg',
#  'lightOFF.717.jpg',
#  'lightOFF.439.jpg',
#  'lightON.969.jpg',
#  'lightOFF.177.jpg',
#  'lightOFF.239.jpg',
#  'lightOFF.156.jpg',
#  'lightON.666.jpg',
#  'lightON.407.jpg',
#  'lightOFF.1011.jpg',
#  'lightOFF.441.jpg',
#  'lightON.74.jpg',
#  'lightOFF.611.jpg',
#  'lightON.273.jpg',
#  'lightOFF.122.jpg',
#  'lightON.203.jpg',
#  'lightOFF.170.jpg',
#  'lightOFF.375.jpg',
#  'lightOFF.623.jpg',
#  'lightON.217.jpg',
#  'lightON.535.jpg',
#  'lightOFF.837.jpg',
#  'lightOFF.943.jpg',
#  'lightON.506.jpg',
#  'lightON.696.jpg',
#  'lightOFF.492.jpg',
#  'lightON.296.jpg',
#  'lightOFF.374.jpg',
#  'lightOFF.232.jpg',
#  'lightON.1034.jpg',
#  'lightON.391.jpg',
#  'lightON.684.jpg',
#  'lightON.310.jpg',
#  'lightOFF.888.jpg',
#  'lightON.226.jpg',
#  'lightOFF.94.jpg',
#  'lightOFF.934.jpg',
#  'lightON.863.jpg',
#  'lightOFF.755.jpg',
#  'lightON.1123.jpg',
#  'lightON.132.jpg',
#  'lightOFF.706.jpg',
#  'lightOFF.502.jpg',
#  'lightOFF.946.jpg',
#  'lightOFF.905.jpg',
#  'lightOFF.649.jpg',
#  'lightOFF.314.jpg',
#  'lightOFF.140.jpg',
#  'lightON.189.jpg',
#  'lightON.719.jpg',
#  'lightON.445.jpg',
#  'lightOFF.709.jpg',
#  'lightOFF.253.jpg',
#  'lightOFF.995.jpg',
#  'lightOFF.1029.jpg',
#  'lightON.285.jpg',
#  'lightON.314.jpg',
#  'lightON.711.jpg',
#  'lightON.16.jpg',
#  'lightON.578.jpg',
#  'lightON.510.jpg',
#  'lightOFF.488.jpg',
#  'lightON.1071.jpg',
#  'lightON.471.jpg',
#  'lightON.1133.jpg',
#  'lightON.289.jpg',
#  'lightON.142.jpg',
#  'lightOFF.257.jpg',
#  'lightON.339.jpg',
#  'lightOFF.624.jpg',
#  'lightON.402.jpg',
#  'lightOFF.737.jpg',
#  'lightOFF.854.jpg',
#  'lightON.760.jpg',
#  'lightOFF.219.jpg',
#  'lightOFF.631.jpg',
#  'lightON.932.jpg',
#  'lightOFF.799.jpg',
#  'lightOFF.1005.jpg',
#  'lightOFF.342.jpg',
#  'lightON.847.jpg',
#  'lightON.740.jpg',
#  'lightOFF.781.jpg',
#  'lightON.748.jpg',
#  'lightON.1130.jpg',
#  'lightON.202.jpg',
#  'lightOFF.472.jpg',
#  'lightOFF.926.jpg',
#  'lightOFF.728.jpg',
#  'lightOFF.741.jpg',
#  'lightOFF.673.jpg',
#  'lightON.167.jpg',
#  'lightON.422.jpg',
#  'lightON.677.jpg',
#  'lightOFF.146.jpg',
#  'lightON.238.jpg',
#  'lightON.204.jpg',
#  'lightON.1016.jpg',
#  'lightOFF.168.jpg',
#  'lightON.93.jpg',
#  'lightOFF.255.jpg',
#  'lightOFF.846.jpg',
#  'lightOFF.71.jpg',
#  'lightON.953.jpg',
#  'lightON.540.jpg',
#  'lightON.483.jpg',
#  'lightON.1072.jpg',
#  'lightON.693.jpg',
#  'lightOFF.343.jpg',
#  'lightON.725.jpg',
#  'lightOFF.768.jpg',
#  'lightOFF.269.jpg',
#  'lightOFF.962.jpg',
#  'lightON.656.jpg',
#  'lightOFF.820.jpg',
#  'lightOFF.772.jpg',
#  'lightOFF.214.jpg',
#  'lightOFF.642.jpg',
#  'lightOFF.994.jpg',
#  'lightOFF.1023.jpg',
#  'lightON.512.jpg',
#  'lightOFF.777.jpg',
#  'lightON.613.jpg',
#  'lightON.211.jpg',
#  'lightOFF.515.jpg',
#  'lightOFF.792.jpg',
#  'lightOFF.985.jpg',
#  'lightON.380.jpg',
#  'lightON.59.jpg',
#  'lightOFF.906.jpg',
#  'lightON.543.jpg',
#  'lightOFF.322.jpg',
#  'lightOFF.725.jpg',
#  'lightOFF.817.jpg',
#  'lightOFF.896.jpg',
#  'lightOFF.855.jpg',
#  'lightON.1055.jpg',
#  'lightOFF.35.jpg',
#  'lightON.641.jpg',
#  'lightON.975.jpg',
#  'lightOFF.702.jpg',
#  'lightOFF.902.jpg',
#  'lightON.946.jpg',
#  'lightON.922.jpg',
#  'lightON.531.jpg',
#  'lightOFF.59.jpg',
#  'lightON.631.jpg',
#  'lightOFF.540.jpg',
#  'lightOFF.711.jpg',
#  'lightOFF.696.jpg',
#  'lightOFF.874.jpg',
#  'lightON.976.jpg',
#  'lightOFF.580.jpg',
#  'lightON.630.jpg',
#  'lightOFF.403.jpg',
#  'lightON.131.jpg',
#  'lightOFF.355.jpg',
#  'lightON.525.jpg',
#  'lightON.150.jpg',
#  'lightOFF.209.jpg',
#  'lightOFF.272.jpg',
#  'lightOFF.835.jpg',
#  'lightON.86.jpg',
#  'lightOFF.974.jpg',
#  'lightON.320.jpg',
#  'lightON.163.jpg',
#  'lightON.479.jpg',
#  'lightOFF.90.jpg',
#  'lightOFF.568.jpg',
#  'lightON.903.jpg',
#  'lightOFF.54.jpg',
#  'lightOFF.1003.jpg',
#  'lightOFF.687.jpg',
#  'lightON.7.jpg',
#  'lightOFF.62.jpg',
#  'lightON.290.jpg',
#  'lightON.1087.jpg',
#  'lightON.929.jpg',
#  'lightON.158.jpg',
#  'lightOFF.968.jpg',
#  'lightON.353.jpg',
#  'lightOFF.130.jpg',
#  'lightON.517.jpg',
#  'lightOFF.453.jpg',
#  'lightOFF.430.jpg',
#  'lightOFF.458.jpg',
#  'lightOFF.126.jpg',
#  'lightOFF.326.jpg',
#  'lightOFF.571.jpg',
#  'lightOFF.904.jpg',
#  'lightON.248.jpg',
#  'lightON.1078.jpg',
#  'lightON.376.jpg',
#  'lightON.616.jpg',
#  'lightOFF.889.jpg',
#  'lightON.761.jpg',
#  'lightON.883.jpg',
#  'lightOFF.353.jpg',
#  'lightON.1124.jpg',
#  'lightON.331.jpg',
#  'lightON.33.jpg',
#  'lightON.1134.jpg',
#  'lightON.31.jpg',
#  'lightOFF.230.jpg',
#  'lightON.280.jpg',
#  'lightON.352.jpg',
#  'lightOFF.542.jpg',
#  'lightOFF.369.jpg',
#  'lightOFF.440.jpg',
#  'lightOFF.128.jpg',
#  'lightON.145.jpg',
#  'lightOFF.259.jpg',
#  'lightOFF.703.jpg',
#  'lightON.480.jpg',
#  'lightOFF.522.jpg',
#  'lightOFF.796.jpg',
#  'lightOFF.150.jpg',
#  'lightOFF.388.jpg',
#  'lightOFF.667.jpg',
#  'lightON.472.jpg',
#  'lightOFF.134.jpg',
#  'lightON.144.jpg',
#  'lightON.403.jpg',
#  'lightON.1009.jpg',
#  'lightOFF.153.jpg',
#  'lightON.1049.jpg',
#  'lightON.1039.jpg',
#  'lightON.1122.jpg',
#  'lightON.436.jpg',
#  'lightOFF.310.jpg',
#  'lightON.184.jpg',
#  'lightOFF.320.jpg',
#  'lightOFF.189.jpg',
#  'lightON.13.jpg',
#  'lightON.746.jpg',
#  'lightON.834.jpg',
#  'lightOFF.291.jpg',
#  'lightOFF.207.jpg',
#  'lightON.667.jpg',
#  'lightON.1105.jpg',
#  'lightON.408.jpg',
#  'lightON.844.jpg',
#  'lightON.439.jpg',
#  'lightOFF.752.jpg',
#  'lightON.943.jpg',
#  'lightON.318.jpg',
#  'lightON.676.jpg',
#  'lightON.447.jpg',
#  'lightOFF.296.jpg',
#  'lightOFF.483.jpg',
#  'lightOFF.1014.jpg',
#  'lightON.995.jpg',
#  'lightOFF.878.jpg',
#  'lightON.416.jpg',
#  'lightOFF.34.jpg',
#  'lightON.117.jpg',
#  'lightON.231.jpg',
#  'lightON.269.jpg',
#  'lightON.122.jpg',
#  'lightOFF.1047.jpg',
#  'lightOFF.594.jpg',
#  'lightOFF.60.jpg',
#  'lightOFF.609.jpg',
#  'lightOFF.335.jpg',
#  'lightON.22.jpg',
#  'lightOFF.174.jpg',
#  'lightON.546.jpg',
#  'lightON.271.jpg',
#  'lightOFF.923.jpg',
#  'lightOFF.193.jpg',
#  'lightON.920.jpg',
#  'lightOFF.764.jpg',
#  'lightON.255.jpg',
#  'lightON.576.jpg',
#  'lightON.105.jpg',
#  'lightOFF.541.jpg',
#  'lightOFF.566.jpg',
#  'lightON.193.jpg',
#  'lightOFF.836.jpg',
#  'lightON.246.jpg',
#  'lightOFF.632.jpg',
#  'lightOFF.630.jpg',
#  'lightOFF.337.jpg',
#  'lightON.1021.jpg',
#  'lightOFF.231.jpg',
#  'lightOFF.664.jpg',
#  'lightOFF.991.jpg',
#  'lightON.611.jpg',
#  'lightOFF.129.jpg',
#  'lightOFF.1018.jpg',
#  'lightOFF.181.jpg',
#  'lightON.901.jpg',
#  'lightON.367.jpg',
#  'lightOFF.731.jpg',
#  'lightON.664.jpg',
#  'lightON.715.jpg',
#  'lightON.753.jpg',
#  'lightON.319.jpg',
#  'lightON.1090.jpg',
#  'lightOFF.733.jpg',
#  'lightON.958.jpg',
#  'lightOFF.435.jpg',
#  'lightOFF.915.jpg',
#  'lightON.17.jpg',
#  'lightON.306.jpg',
#  'lightON.441.jpg',
#  'lightON.935.jpg',
#  'lightON.272.jpg',
#  'lightOFF.123.jpg',
#  'lightOFF.216.jpg',
#  'lightON.690.jpg',
#  'lightOFF.616.jpg',
#  'lightON.924.jpg',
#  'lightON.926.jpg',
#  'lightOFF.790.jpg',
#  'lightOFF.945.jpg',
#  'lightOFF.645.jpg',
#  'lightOFF.805.jpg',
#  'lightOFF.840.jpg',
#  'lightOFF.700.jpg',
#  'lightOFF.639.jpg',
#  'lightOFF.600.jpg',
#  'lightON.363.jpg',
#  'lightON.595.jpg',
#  'lightON.816.jpg',
#  'lightON.542.jpg',
#  'lightON.1031.jpg',
#  'lightON.1099.jpg',
#  'lightON.1023.jpg',
#  'lightOFF.387.jpg',
#  'lightOFF.478.jpg',
#  'lightON.526.jpg',
#  'lightOFF.856.jpg',
#  'lightOFF.133.jpg',
#  'lightOFF.327.jpg',
#  'lightON.197.jpg',
#  'lightON.782.jpg',
#  'lightOFF.686.jpg',
#  'lightON.134.jpg',
#  'lightON.228.jpg',
#  'lightOFF.36.jpg',
#  'lightON.292.jpg',
#  'lightOFF.304.jpg',
#  'lightON.245.jpg',
#  'lightON.90.jpg',
#  'lightOFF.445.jpg',
#  'lightON.252.jpg',
#  'lightOFF.561.jpg',
#  'lightOFF.490.jpg',
#  'lightON.5.jpg',
#  'lightON.398.jpg',
#  'lightOFF.273.jpg',
#  'lightON.281.jpg',
#  'lightOFF.573.jpg',
#  'lightON.78.jpg',
#  'lightON.448.jpg',
#  'lightOFF.178.jpg',
#  'lightON.1086.jpg',
#  'lightOFF.669.jpg',
#  'lightON.328.jpg',
#  'lightON.43.jpg',
#  'lightON.1092.jpg',
#  'lightOFF.218.jpg',
#  'lightON.1064.jpg',
#  'lightON.714.jpg',
#  'lightOFF.620.jpg',
#  'lightOFF.1025.jpg',
#  'lightON.964.jpg',
#  'lightOFF.31.jpg',
#  'lightON.414.jpg',
#  'lightOFF.465.jpg',
#  'lightON.971.jpg',
#  'lightOFF.393.jpg',
#  'lightON.424.jpg',
#  'lightON.967.jpg',
#  'lightON.216.jpg',
#  'lightOFF.659.jpg',
#  'lightON.931.jpg',
#  'lightON.1106.jpg',
#  'lightOFF.677.jpg',
#  'lightOFF.114.jpg',
#  'lightOFF.173.jpg',
#  'lightON.839.jpg',
#  'lightOFF.789.jpg',
#  'lightOFF.354.jpg',
#  'lightOFF.206.jpg',
#  'lightOFF.603.jpg',
#  'lightON.1002.jpg',
#  'lightON.508.jpg',
#  'lightON.138.jpg',
#  'lightOFF.306.jpg',
#  'lightOFF.808.jpg',
#  'lightON.750.jpg',
#  'lightON.295.jpg',
#  'lightON.14.jpg',
#  'lightOFF.996.jpg',
#  'lightOFF.710.jpg',
#  'lightOFF.454.jpg',
#  'lightOFF.708.jpg',
#  'lightON.751.jpg',
#  'lightON.154.jpg',
#  'lightOFF.998.jpg',
#  'lightOFF.818.jpg',
#  'lightON.749.jpg',
#  'lightOFF.830.jpg',
#  'lightOFF.734.jpg',
#  'lightON.485.jpg',
#  'lightOFF.929.jpg',
#  'lightOFF.605.jpg',
#  'lightOFF.67.jpg',
#  'lightOFF.718.jpg',
#  'lightOFF.376.jpg',
#  'lightON.978.jpg',
#  'lightOFF.532.jpg',
#  'lightON.874.jpg',
#  'lightOFF.235.jpg',
#  'lightON.940.jpg',
#  'lightON.139.jpg',
#  'lightON.258.jpg',
#  'lightOFF.955.jpg',
#  'lightOFF.169.jpg',
#  'lightOFF.344.jpg',
#  'lightON.266.jpg',
#  'lightON.481.jpg',
#  'lightOFF.646.jpg',
#  'lightON.305.jpg',
#  'lightON.259.jpg',
#  'lightON.770.jpg',
#  'lightOFF.1013.jpg',
#  'lightON.152.jpg',
#  'lightON.430.jpg',
#  'lightON.1019.jpg',
#  'lightOFF.73.jpg',
#  'lightOFF.318.jpg',
#  'lightOFF.237.jpg',
#  'lightOFF.407.jpg',
#  'lightON.330.jpg',
#  'lightON.1077.jpg',
#  'lightON.299.jpg',
#  'lightOFF.670.jpg',
#  'lightOFF.562.jpg',
#  'lightOFF.65.jpg',
#  'lightOFF.724.jpg',
#  'lightON.6.jpg',
#  'lightOFF.319.jpg',
#  'lightON.1059.jpg',
#  'lightOFF.931.jpg',
#  'lightOFF.378.jpg',
#  'lightON.905.jpg',
#  'lightON.878.jpg',
#  'lightOFF.876.jpg',
#  'lightON.624.jpg',
#  'lightOFF.119.jpg',
#  'lightON.166.jpg',
#  'lightON.48.jpg',
#  'lightOFF.284.jpg',
#  'lightON.706.jpg',
#  'lightOFF.400.jpg',
#  'lightON.230.jpg',
#  'lightON.61.jpg',
#  'lightON.812.jpg',
#  'lightON.70.jpg',
#  'lightOFF.104.jpg',
#  'lightOFF.395.jpg',
#  'lightON.356.jpg',
#  'lightOFF.959.jpg',
#  'lightON.727.jpg',
#  'lightON.19.jpg',
#  'lightON.265.jpg',
#  'lightOFF.745.jpg',
#  'lightOFF.873.jpg',
#  'lightOFF.775.jpg',
#  'lightON.44.jpg',
#  'lightON.466.jpg',
#  'lightON.955.jpg',
#  'lightOFF.394.jpg',
#  'lightON.917.jpg',
#  'lightOFF.293.jpg',
#  'lightON.745.jpg',
#  'lightON.151.jpg',
#  'lightOFF.328.jpg',
#  'lightON.501.jpg',
#  'lightON.598.jpg',
#  'lightON.956.jpg',
#  'lightON.762.jpg',
#  'lightON.1020.jpg',
#  'lightON.209.jpg',
#  'lightON.411.jpg',
#  'lightOFF.135.jpg',
#  'lightOFF.791.jpg',
#  'lightON.297.jpg',
#  'lightON.80.jpg',
#  'lightON.1056.jpg',
#  'lightON.966.jpg',
#  'lightON.208.jpg',
#  'lightOFF.984.jpg',
#  'lightOFF.744.jpg',
#  'lightON.970.jpg',
#  'lightOFF.615.jpg',
#  'lightOFF.305.jpg',
#  'lightOFF.21.jpg',
#  'lightON.645.jpg',
#  'lightOFF.143.jpg',
#  'lightON.552.jpg',
#  'lightOFF.644.jpg',
#  'lightOFF.149.jpg',
#  'lightOFF.16.jpg',
#  'lightOFF.425.jpg',
#  'lightOFF.109.jpg',
#  'lightOFF.770.jpg',
#  'lightOFF.362.jpg',
#  'lightON.902.jpg',
#  'lightOFF.890.jpg',
#  'lightOFF.78.jpg',
#  ...]

# %%
light_names = os.listdir(path)
on_off_labels = [each.split('.')[0] for each in light_names]
on_off_file_id =[each.split('.')[1] for each in light_names]

# %%
len(light_names)
# Out:
# 2169

# %%
# import random
# import matplotlib.pyplot as plt
# import matplotlib.image as mpimg
# %matplotlib inline

sample = random.choice(light_names)
image = mpimg.imread(path + sample)
plt.imshow(image)
plt.show()

# %%
sample = random.choice(light_names)
image = mpimg.imread(path+ sample)
image.shape
# Out:
# (1280, 720, 3)

# %%
from skimage.transform import resize
resized = resize(image, (195, 195, 3)) #300, 300 크기로 변경

fig, axes = plt.subplots(1, 2, figsize =(8, 4))
ax = axes.ravel()

ax[0].imshow(image, cmap = plt.cm.gray)
ax[0].set_title("light_on_off_image")
ax[1].imshow(resized, cmap =plt.cm.gray)
ax[1].set_title("resized_light_on_off_check_image")

fig.tight_layout()
plt.show()

# %%
from tqdm.notebook import tqdm
from skimage.color import rgb2gray
import numpy as np

images = []
bar_total = tqdm(light_names)
for file in bar_total:
    image = mpimg.imread(path+file)
    images.append(resize(image, (195, 195, 3)))

images = np.array(images)
# Out:
#   0%|          | 0/2169 [00:00<?, ?it/s]

# %%
images.shape, light_names[:5]
# Out:
# ((2169, 195, 195, 3),
#  ['lightOFF.240.jpg',
#   'lightOFF.530.jpg',
#   'lightON.1073.jpg',
#   'lightON.852.jpg',
#   'lightOFF.80.jpg'])

# %%
images[:3]
# Out:
# array([[[[0.67345734, 0.63652984, 0.62147499],
#          [0.67509468, 0.63697647, 0.62583618],
#          [0.69123553, 0.65216332, 0.64615404],
#          ...,
#          [0.54708965, 0.51114174, 0.48183721],
#          [0.55052774, 0.51457983, 0.4852753 ],
#          [0.55179173, 0.51584382, 0.48653929]],
#
#         [[0.6513041 , 0.61596885, 0.58943329],
#          [0.65413532, 0.61843023, 0.59676441],
#          [0.67258083, 0.63569691, 0.62068554],
#          ...,
#          [0.54457306, 0.51667737, 0.49391894],
#          [0.5483244 , 0.52042871, 0.49767028],
#          [0.50903549, 0.4811398 , 0.45838137]],
#
#         [[0.64019139, 0.60489727, 0.57926039],
#          [0.65766312, 0.62236712, 0.59935922],
#          [0.65526877, 0.61990656, 0.59993366],
#          ...,
#          [0.54403466, 0.5173993 , 0.50345641],
#          [0.51190095, 0.48526558, 0.4713227 ],
#          [0.46888711, 0.44225175, 0.42830886]],
#
#         ...,
#
#         [[0.34397941, 0.33622519, 0.35022273],
#          [0.32691811, 0.31916442, 0.3319089 ],
#          [0.30853244, 0.30117072, 0.31048163],
#          ...,
#          [0.31295234, 0.26981509, 0.25412881],
#          [0.31326031, 0.27012306, 0.25443678],
#          [0.31327305, 0.2701358 , 0.25444952]],
#
#         [[0.70705959, 0.69921645, 0.7109837 ],
#          [0.71547638, 0.7076349 , 0.71660092],
#          [0.71503462, 0.70830174, 0.70909462],
#          ...,
#          [0.30977401, 0.26663675, 0.25095048],
#          [0.30921494, 0.26607769, 0.25039141],
#          [0.30919172, 0.26605447, 0.25036819]],
#
#         [[0.7240434 , 0.71620026, 0.72795288],
#          [0.72934829, 0.72150687, 0.73041768],
#          [0.73271868, 0.72601776, 0.72659538],
#          ...,
#          [0.30978392, 0.26664667, 0.25096039],
#          [0.3097007 , 0.26656344, 0.25087717],
#          [0.30969724, 0.26655999, 0.25087371]]],
#
#
#        [[[0.57397709, 0.57005552, 0.55436925],
#          [0.59598241, 0.59206084, 0.57637456],
#          [0.5997762 , 0.59585463, 0.58016836],
#          ...,
#          [0.62041619, 0.60865149, 0.58120051],
#          [0.63207865, 0.62031394, 0.59286296],
#          [0.62883352, 0.61706882, 0.58961783]],
#
#         [[0.60111289, 0.59719132, 0.58150505],
#          [0.60623825, 0.60231668, 0.5866304 ],
#          [0.59255078, 0.58862921, 0.57294294],
#          ...,
#          [0.62897743, 0.61735864, 0.58986008],
#          [0.61806978, 0.60645099, 0.57895243],
#          [0.61484493, 0.60322615, 0.57572759]],
#
#         [[0.61707217, 0.61315061, 0.59746433],
#          [0.61530069, 0.61137912, 0.59569285],
#          [0.5785272 , 0.57460563, 0.55891936],
#          ...,
#          [0.63107733, 0.62252219, 0.59478923],
#          [0.55921931, 0.55066416, 0.5229312 ],
#          [0.57522521, 0.56667007, 0.53893711]],
#
#         ...,
#
#         [[0.52204413, 0.49021015, 0.45756896],
#          [0.52373997, 0.49190599, 0.4592648 ],
#          [0.52723041, 0.49539643, 0.46275524],
#          ...,
#          [0.18823252, 0.25489919, 0.52767892],
#          [0.18748324, 0.25414991, 0.52692964],
#          [0.18607108, 0.25273774, 0.52551748]],
#
#         [[0.49884431, 0.47128159, 0.4322335 ],
#          [0.50169521, 0.4741325 , 0.43508441],
#          [0.4988088 , 0.47124608, 0.43219799],
#          ...,
#          [0.18823522, 0.25490189, 0.52554599],
#          [0.18821612, 0.25488279, 0.52552689],
#          [0.18818012, 0.25484679, 0.52549089]],
#
#         [[0.49428861, 0.46683763, 0.42762194],
#          [0.49089691, 0.46344593, 0.42423024],
#          [0.48617577, 0.45872479, 0.4195091 ],
#          ...,
#          [0.18823529, 0.25490196, 0.5254902 ],
#          [0.18823529, 0.25490196, 0.5254902 ],
#          [0.18823529, 0.25490196, 0.5254902 ]]],
#
#
#        [[[0.60175228, 0.59390914, 0.59783071],
#          [0.61269006, 0.60484692, 0.60876849],
#          [0.63345001, 0.62560688, 0.62952844],
#          ...,
#          [0.43135926, 0.42351612, 0.42743769],
#          [0.43111189, 0.42326875, 0.42719032],
#          [0.43096833, 0.42312519, 0.42704676]],
#
#         [[0.62105531, 0.61321217, 0.61713374],
#          [0.62046885, 0.61262571, 0.61654728],
#          [0.63539457, 0.62755143, 0.631473  ],
#          ...,
#          [0.42996543, 0.42217815, 0.42593213],
#          [0.42351457, 0.4157273 , 0.41948127],
#          [0.40688931, 0.39910204, 0.40285601]],
#
#         [[0.58953399, 0.58169085, 0.58561242],
#          [0.59511798, 0.58727484, 0.59119641],
#          [0.61656079, 0.60871766, 0.61263923],
#          ...,
#          [0.39847233, 0.39282069, 0.39016776],
#          [0.40144902, 0.39579738, 0.39314445],
#          [0.41135732, 0.40570568, 0.40305276]],
#
#         ...,
#
#         [[0.8436868 , 0.83584367, 0.84760837],
#          [0.33286766, 0.32502452, 0.33678923],
#          [0.23491534, 0.22707221, 0.23883691],
#          ...,
#          [0.06839674, 0.0605536 , 0.07231831],
#          [0.06839674, 0.0605536 , 0.07231831],
#          [0.06839674, 0.0605536 , 0.07231831]],
#
#         [[0.88263716, 0.87479402, 0.88655873],
#          [0.43509964, 0.42725651, 0.43902121],
#          [0.23437138, 0.22652824, 0.23829295],
#          ...,
#          [0.07053237, 0.06268923, 0.07445394],
#          [0.07053237, 0.06268923, 0.07445394],
#          [0.07053237, 0.06268923, 0.07445394]],
#
#         [[0.89575698, 0.88791384, 0.89967855],
#          [0.56241531, 0.55457218, 0.56633688],
#          [0.24005779, 0.23221465, 0.24397936],
#          ...,
#          [0.07058824, 0.0627451 , 0.0745098 ],
#          [0.07058824, 0.0627451 , 0.0745098 ],
#          [0.07058824, 0.0627451 , 0.0745098 ]]]])

# %%
from sklearn.preprocessing import LabelEncoder

encoder = LabelEncoder()
encoder.fit(on_off_labels)
light_on_off_labels_encoded = encoder.transform(on_off_labels)
light_on_off_labels_encoded[:3], encoder.classes_
# Out:
# (array([0, 0, 1]), array(['lightOFF', 'lightON'], dtype='<U8'))

# %%
# 1.12 데이터 나누고

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train , y_test =\
                train_test_split(images, light_on_off_labels_encoded, test_size =0.2,
                                 random_state = 13, stratify  = light_on_off_labels_encoded)
X_train.shape, X_test.shape
# Out:
# ((1735, 195, 195, 3), (434, 195, 195, 3))

# %%
samples = random.choices(population = range(0, 244), k =8 )

plt.figure(figsize =(14,12))
for idx, n in enumerate(samples):
    plt.subplot(2, 4, idx+1)
    plt.imshow(X_train[n], cmap ='Greys',interpolation = 'nearest')
    plt.title(y_train[n])

plt.tight_layout()
plt.show()

# %%
from tensorflow.keras import layers, models

model = models.Sequential([layers.Conv2D(32,(3,3), activation ='relu', input_shape=(195,195,3)),
                           layers.MaxPooling2D(pool_size=(2,2), strides =(2,2)),
                           layers.Dropout(0.25),
                           
                           layers.Conv2D(64,(3,3), activation='relu',padding ='same'),
                           layers.MaxPooling2D(pool_size=(2,2)),
                           layers.Dropout(0.25),

                           layers.Conv2D(64,(3,3), activation='relu',padding ='same'),
                           layers.MaxPooling2D(pool_size=(2,2)),
                           layers.Dropout(0.25),
                           
                           layers.Flatten(),
                           layers.Dense(512, activation ='relu'),
                           layers.Dropout(0.25),
                           layers.Dense(2, activation ='softmax')])



model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 193, 193, 32)      896
#
#  max_pooling2d (MaxPooling2  (None, 96, 96, 32)        0
#  D)
#
#  dropout (Dropout)           (None, 96, 96, 32)        0
#
#  conv2d_1 (Conv2D)           (None, 96, 96, 64)        18496
#
#  max_pooling2d_1 (MaxPoolin  (None, 48, 48, 64)        0
#  g2D)
#
#  dropout_1 (Dropout)         (None, 48, 48, 64)        0
#
#  conv2d_2 (Conv2D)           (None, 48, 48, 64)        36928
#
#  max_pooling2d_2 (MaxPoolin  (None, 24, 24, 64)        0
#  g2D)
#
#  dropout_2 (Dropout)         (None, 24, 24, 64)        0
#
#  flatten (Flatten)           (None, 36864)             0
#
#  dense (Dense)               (None, 512)               18874880
#
#  dropout_3 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 2)                 1026
#
# =================================================================
# Total params: 18932226 (72.22 MB)
# Trainable params: 18932226 (72.22 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# 2023-11-22 14:22:46.100939: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-22 14:22:46.101183: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-22 14:22:46.101544: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-22 14:22:46.830422: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-22 14:22:46.830645: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-22 14:22:46.830796: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-22 14:22:46.830883: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1886] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 3874 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 2060, pci bus id: 0000:01:00.0, compute capability: 7.5

# %%
model.compile(optimizer='adam', loss = 'sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
import time

start_time = time.time()
hist = model.fit(X_train.reshape(1735, 195, 195, 3), y_train,
                 epochs = 20, verbose =1, #처음 5번
                 validation_data = (X_test.reshape(434, 195, 195, 3), y_test))
print("fit time :", time.time() - start_time)
# Out:
# 2023-11-22 14:22:51.463993: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 791680500 exceeds 10% of free system memory.
# 2023-11-22 14:22:51.977197: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 791680500 exceeds 10% of free system memory.
# Epoch 1/20
# 2023-11-22 14:22:53.028762: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:961] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape insequential/dropout/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 2023-11-22 14:22:54.626534: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:442] Loaded cuDNN version 8800
# 2023-11-22 14:22:57.873660: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x558a12d6af50 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-11-22 14:22:57.873822: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 2060, Compute Capability 7.5
# 2023-11-22 14:22:57.887319: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-11-22 14:22:57.990906: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 55/55 [==============================] - 13s 108ms/step - loss: 1.2676 - accuracy: 0.5349 - val_loss: 0.6645 - val_accuracy: 0.7857
# Epoch 2/20
# 55/55 [==============================] - 4s 67ms/step - loss: 0.5411 - accuracy: 0.7568 - val_loss: 0.3394 - val_accuracy: 0.9217
# Epoch 3/20
# 55/55 [==============================] - 4s 67ms/step - loss: 0.2921 - accuracy: 0.8945 - val_loss: 0.1854 - val_accuracy: 0.9401
# Epoch 4/20
# 55/55 [==============================] - 4s 68ms/step - loss: 0.1672 - accuracy: 0.9504 - val_loss: 0.1496 - val_accuracy: 0.9585
# Epoch 5/20
# 55/55 [==============================] - 4s 68ms/step - loss: 0.0849 - accuracy: 0.9781 - val_loss: 0.0676 - val_accuracy: 0.9816
# Epoch 6/20
# 55/55 [==============================] - 4s 69ms/step - loss: 0.0945 - accuracy: 0.9764 - val_loss: 0.1526 - val_accuracy: 0.9539
# Epoch 7/20
# 55/55 [==============================] - 4s 73ms/step - loss: 0.0585 - accuracy: 0.9839 - val_loss: 0.0692 - val_accuracy: 0.9793
# Epoch 8/20
# 55/55 [==============================] - 6s 109ms/step - loss: 0.0390 - accuracy: 0.9914 - val_loss: 0.0704 - val_accuracy: 0.9793
# Epoch 9/20
# 55/55 [==============================] - 84s 2s/step - loss: 0.0436 - accuracy: 0.9885 - val_loss: 0.0762 - val_accuracy: 0.9793
# Epoch 10/20
# 55/55 [==============================] - 4s 66ms/step - loss: 0.0714 - accuracy: 0.9758 - val_loss: 0.1287 - val_accuracy: 0.9700
# Epoch 11/20
# 55/55 [==============================] - 4s 68ms/step - loss: 0.0381 - accuracy: 0.9850 - val_loss: 0.0800 - val_accuracy: 0.9793
# Epoch 12/20
# 55/55 [==============================] - 4s 68ms/step - loss: 0.0081 - accuracy: 0.9983 - val_loss: 0.0596 - val_accuracy: 0.9816
# Epoch 13/20
# 55/55 [==============================] - 4s 68ms/step - loss: 0.0071 - accuracy: 0.9977 - val_loss: 0.0755 - val_accuracy: 0.9793
# Epoch 14/20
# 55/55 [==============================] - 4s 68ms/step - loss: 0.0050 - accuracy: 0.9983 - val_loss: 0.0552 - val_accuracy: 0.9839
# Epoch 15/20
# 55/55 [==============================] - 4s 68ms/step - loss: 0.0076 - accuracy: 0.9977 - val_loss: 0.0745 - val_accuracy: 0.9793
# Epoch 16/20
# 55/55 [==============================] - 4s 69ms/step - loss: 0.0034 - accuracy: 0.9994 - val_loss: 0.0686 - val_accuracy: 0.9816
# Epoch 17/20
# 55/55 [==============================] - 4s 72ms/step - loss: 0.0034 - accuracy: 0.9983 - val_loss: 0.0646 - val_accuracy: 0.9770
# Epoch 18/20
# 55/55 [==============================] - 4s 71ms/step - loss: 0.0071 - accuracy: 0.9983 - val_loss: 0.0490 - val_accuracy: 0.9885
# Epoch 19/20
# 55/55 [==============================] - 4s 71ms/step - loss: 0.0022 - accuracy: 0.9994 - val_loss: 0.0678 - val_accuracy: 0.9816
# Epoch 20/20
# 55/55 [==============================] - 4s 68ms/step - loss: 0.0024 - accuracy: 0.9988 - val_loss: 0.0684 - val_accuracy: 0.9816
# fit time : 173.13640236854553

# %%
score = model.evaluate(X_test, y_test)
print('Test loss :', score[0])
print('Test accuracy :', score[1])
# Out:
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0684 - accuracy: 0.9816
# Test loss : 0.06839192658662796
# Test accuracy : 0.981566846370697

# %%
plot_target = ['loss', 'val_loss', 'accuracy', 'val_accuracy']
plt.figure(figsize=(12,8))

for each in plot_target:
    plt.plot(hist.history[each], label = each)
plt.legend()
plt.grid()
plt.show()

# %%
import matplotlib
print(matplotlib.__version__)
# Out:
# 3.8.1

# %%
import numpy as np
predicted_result = model.predict(X_test)
predicted_labels = np.argmax(predicted_result, axis=1)
predicted_labels[:10]
# Out:
# 14/14 [==============================] - 0s 11ms/step
# array([1, 0, 1, 1, 1, 1, 1, 1, 1, 0])

# %%
wrong_result =[]

for n in range(0, len(y_test)):
    if predicted_labels[n] != y_test[n]:
        wrong_result.append(n)
len(wrong_result)
# Out:
# 8

# %%
plt.figure(figsize =(14,12))

for idx, n in enumerate(wrong_result):
    plt.subplot(2, 4, idx +1)
    plt.imshow(X_test[n], cmap='Greys', interpolation='nearest')
    plt.title('Label :' + str(y_test[n])+ ' Predict :' + str(predicted_labels[n]))
    plt.axis('off')

plt.show()
