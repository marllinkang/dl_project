# %%
import tensorflow as tf
# Out:
# 2023-11-17 15:52:02.078953: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-17 15:52:02.078978: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-17 15:52:02.079945: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-11-17 15:52:02.169955: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-11-17 15:52:03.173120: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
tf.config.list_physical_devices("GPU")
# Out:
# 2023-11-17 15:52:05.194809: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# 2023-11-17 15:52:05.353998: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-17 15:52:05.354267: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355

# %%
import cv2
from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.applications.vgg16 import preprocess_input, decode_predictions
import random
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline

# %%
import os
path = "../../dl_project/light_on/light_on_off/"
os.listdir(path)
# Out:
# ['lightOFF.240.jpg',
#  'lightOFF.530.jpg',
#  'lightON.852.jpg',
#  'lightOFF.80.jpg',
#  'lightON.34.jpg',
#  'lightOFF.576.jpg',
#  'lightON.759.jpg',
#  'lightOFF.184.jpg',
#  'lightOFF.208.jpg',
#  'lightON.236.jpg',
#  'lightOFF.83.jpg',
#  'lightON.474.jpg',
#  'lightOFF.42.jpg',
#  'lightON.293.jpg',
#  'lightOFF.448.jpg',
#  'lightON.496.jpg',
#  'lightOFF.726.jpg',
#  'lightOFF.56.jpg',
#  'lightOFF.882.jpg',
#  'lightOFF.101.jpg',
#  'lightON.52.jpg',
#  'lightOFF.675.jpg',
#  'lightOFF.828.jpg',
#  'lightON.741.jpg',
#  'lightOFF.581.jpg',
#  'lightOFF.85.jpg',
#  'lightON.562.jpg',
#  'lightOFF.99.jpg',
#  'lightON.176.jpg',
#  'lightOFF.251.jpg',
#  'lightON.771.jpg',
#  'lightON.584.jpg',
#  'lightOFF.142.jpg',
#  'lightOFF.491.jpg',
#  'lightON.102.jpg',
#  'lightOFF.671.jpg',
#  'lightON.169.jpg',
#  'lightOFF.421.jpg',
#  'lightOFF.592.jpg',
#  'lightOFF.452.jpg',
#  'lightON.790.jpg',
#  'lightON.207.jpg',
#  'lightON.794.jpg',
#  'lightON.38.jpg',
#  'lightON.887.jpg',
#  'lightOFF.608.jpg',
#  'lightON.42.jpg',
#  'lightOFF.688.jpg',
#  'lightON.784.jpg',
#  'lightOFF.103.jpg',
#  'lightON.626.jpg',
#  'lightON.509.jpg',
#  'lightON.811.jpg',
#  'lightON.537.jpg',
#  'lightON.419.jpg',
#  'lightOFF.713.jpg',
#  'lightOFF.838.jpg',
#  'lightOFF.690.jpg',
#  'lightON.343.jpg',
#  'lightON.417.jpg',
#  'lightOFF.432.jpg',
#  'lightOFF.317.jpg',
#  'lightON.484.jpg',
#  'lightOFF.556.jpg',
#  'lightON.640.jpg',
#  'lightON.54.jpg',
#  'lightON.392.jpg',
#  'lightON.374.jpg',
#  'lightOFF.52.jpg',
#  'lightON.662.jpg',
#  'lightOFF.7.jpg',
#  'lightOFF.417.jpg',
#  'lightOFF.89.jpg',
#  'lightON.194.jpg',
#  'lightOFF.538.jpg',
#  'lightON.793.jpg',
#  'lightOFF.201.jpg',
#  'lightON.160.jpg',
#  'lightON.695.jpg',
#  'lightON.83.jpg',
#  'lightON.565.jpg',
#  'lightON.30.jpg',
#  'lightOFF.265.jpg',
#  'lightON.832.jpg',
#  'lightON.10.jpg',
#  'lightOFF.705.jpg',
#  'lightOFF.250.jpg',
#  'lightON.351.jpg',
#  'lightON.446.jpg',
#  'lightON.279.jpg',
#  'lightON.55.jpg',
#  'lightON.386.jpg',
#  'lightON.384.jpg',
#  'lightOFF.565.jpg',
#  'lightON.468.jpg',
#  'lightON.842.jpg',
#  'lightOFF.864.jpg',
#  'lightOFF.869.jpg',
#  'lightON.25.jpg',
#  'lightOFF.333.jpg',
#  'lightOFF.693.jpg',
#  'lightOFF.638.jpg',
#  'lightOFF.461.jpg',
#  'lightOFF.200.jpg',
#  'lightOFF.426.jpg',
#  'lightON.804.jpg',
#  'lightOFF.267.jpg',
#  'lightON.322.jpg',
#  'lightOFF.1.jpg',
#  'lightON.165.jpg',
#  'lightOFF.82.jpg',
#  'lightOFF.810.jpg',
#  'lightOFF.279.jpg',
#  'lightOFF.8.jpg',
#  'lightON.444.jpg',
#  'lightON.588.jpg',
#  'lightON.700.jpg',
#  'lightON.659.jpg',
#  'lightOFF.783.jpg',
#  'lightOFF.812.jpg',
#  'lightOFF.413.jpg',
#  'lightOFF.769.jpg',
#  'lightON.731.jpg',
#  'lightOFF.408.jpg',
#  'lightOFF.15.jpg',
#  'lightON.341.jpg',
#  'lightON.639.jpg',
#  'lightON.625.jpg',
#  'lightON.872.jpg',
#  'lightOFF.108.jpg',
#  'lightON.72.jpg',
#  'lightOFF.494.jpg',
#  'lightOFF.682.jpg',
#  'lightON.378.jpg',
#  'lightOFF.583.jpg',
#  'lightON.838.jpg',
#  'lightON.87.jpg',
#  'lightON.460.jpg',
#  'lightOFF.79.jpg',
#  'lightOFF.346.jpg',
#  'lightOFF.357.jpg',
#  'lightON.777.jpg',
#  'lightON.317.jpg',
#  'lightON.660.jpg',
#  'lightOFF.13.jpg',
#  'lightOFF.442.jpg',
#  'lightON.77.jpg',
#  'lightOFF.593.jpg',
#  'lightOFF.364.jpg',
#  'lightON.492.jpg',
#  'lightOFF.243.jpg',
#  'lightOFF.167.jpg',
#  'lightON.459.jpg',
#  'lightON.712.jpg',
#  'lightOFF.383.jpg',
#  'lightON.155.jpg',
#  'lightOFF.821.jpg',
#  'lightON.523.jpg',
#  'lightON.827.jpg',
#  'lightON.686.jpg',
#  'lightON.106.jpg',
#  'lightON.555.jpg',
#  'lightOFF.798.jpg',
#  'lightON.573.jpg',
#  'lightOFF.248.jpg',
#  'lightON.438.jpg',
#  'lightOFF.482.jpg',
#  'lightON.355.jpg',
#  'lightON.321.jpg',
#  'lightOFF.786.jpg',
#  'lightOFF.110.jpg',
#  'lightOFF.382.jpg',
#  'lightOFF.803.jpg',
#  'lightOFF.519.jpg',
#  'lightON.393.jpg',
#  'lightON.685.jpg',
#  'lightON.633.jpg',
#  'lightOFF.336.jpg',
#  'lightOFF.5.jpg',
#  'lightOFF.77.jpg',
#  'lightON.243.jpg',
#  'lightON.383.jpg',
#  'lightON.591.jpg',
#  'lightOFF.270.jpg',
#  'lightOFF.450.jpg',
#  'lightON.486.jpg',
#  'lightON.190.jpg',
#  'lightON.218.jpg',
#  'lightOFF.349.jpg',
#  'lightOFF.74.jpg',
#  'lightOFF.680.jpg',
#  'lightON.781.jpg',
#  'lightOFF.857.jpg',
#  'lightON.111.jpg',
#  'lightOFF.55.jpg',
#  'lightOFF.136.jpg',
#  'lightON.524.jpg',
#  'lightOFF.479.jpg',
#  'lightOFF.459.jpg',
#  'lightON.27.jpg',
#  'lightOFF.525.jpg',
#  'lightON.94.jpg',
#  'lightOFF.281.jpg',
#  'lightON.300.jpg',
#  'lightOFF.535.jpg',
#  'lightON.104.jpg',
#  'lightON.679.jpg',
#  'lightON.149.jpg',
#  'lightON.191.jpg',
#  'lightON.657.jpg',
#  'lightON.311.jpg',
#  'lightON.359.jpg',
#  'lightON.112.jpg',
#  'lightON.527.jpg',
#  'lightON.41.jpg',
#  'lightON.369.jpg',
#  'lightOFF.356.jpg',
#  'lightOFF.588.jpg',
#  'lightOFF.495.jpg',
#  'lightON.244.jpg',
#  'lightOFF.307.jpg',
#  'lightON.514.jpg',
#  'lightOFF.183.jpg',
#  'lightOFF.473.jpg',
#  'lightON.815.jpg',
#  'lightON.845.jpg',
#  'lightOFF.721.jpg',
#  'lightOFF.46.jpg',
#  'lightON.239.jpg',
#  'lightON.18.jpg',
#  'lightOFF.402.jpg',
#  'lightON.730.jpg',
#  'lightON.683.jpg',
#  'lightOFF.191.jpg',
#  'lightON.843.jpg',
#  'lightOFF.722.jpg',
#  'lightON.206.jpg',
#  'lightOFF.825.jpg',
#  'lightOFF.329.jpg',
#  'lightON.895.jpg',
#  'lightON.718.jpg',
#  'lightON.172.jpg',
#  'lightON.434.jpg',
#  'lightON.652.jpg',
#  'lightON.593.jpg',
#  'lightON.32.jpg',
#  'lightOFF.164.jpg',
#  'lightOFF.773.jpg',
#  'lightON.199.jpg',
#  'lightON.810.jpg',
#  'lightON.851.jpg',
#  'lightON.549.jpg',
#  'lightON.544.jpg',
#  'lightON.431.jpg',
#  'lightOFF.48.jpg',
#  'lightOFF.443.jpg',
#  'lightOFF.470.jpg',
#  'lightON.440.jpg',
#  'lightON.566.jpg',
#  'lightOFF.68.jpg',
#  'lightOFF.529.jpg',
#  'lightON.580.jpg',
#  'lightOFF.406.jpg',
#  'lightON.671.jpg',
#  'lightON.502.jpg',
#  'lightON.450.jpg',
#  'lightON.225.jpg',
#  'lightOFF.689.jpg',
#  'lightON.449.jpg',
#  'lightON.242.jpg',
#  'lightOFF.521.jpg',
#  'lightOFF.766.jpg',
#  'lightOFF.740.jpg',
#  'lightOFF.385.jpg',
#  'lightON.614.jpg',
#  'lightON.382.jpg',
#  'lightOFF.244.jpg',
#  'lightOFF.489.jpg',
#  'lightOFF.723.jpg',
#  'lightON.682.jpg',
#  'lightOFF.20.jpg',
#  'lightOFF.739.jpg',
#  'lightOFF.398.jpg',
#  'lightOFF.431.jpg',
#  'lightON.807.jpg',
#  'lightON.592.jpg',
#  'lightON.137.jpg',
#  'lightOFF.587.jpg',
#  'lightON.1.jpg',
#  'lightOFF.86.jpg',
#  'lightON.148.jpg',
#  'lightOFF.198.jpg',
#  'lightOFF.405.jpg',
#  'lightON.648.jpg',
#  'lightOFF.61.jpg',
#  'lightOFF.194.jpg',
#  'lightOFF.509.jpg',
#  'lightOFF.221.jpg',
#  'lightOFF.574.jpg',
#  'lightON.326.jpg',
#  'lightON.11.jpg',
#  'lightOFF.363.jpg',
#  'lightOFF.523.jpg',
#  'lightOFF.203.jpg',
#  'lightON.338.jpg',
#  'lightON.39.jpg',
#  'lightON.162.jpg',
#  'lightOFF.510.jpg',
#  'lightOFF.585.jpg',
#  'lightON.498.jpg',
#  'lightOFF.165.jpg',
#  'lightOFF.756.jpg',
#  'lightON.433.jpg',
#  'lightON.687.jpg',
#  'lightON.428.jpg',
#  'lightOFF.330.jpg',
#  'lightOFF.381.jpg',
#  'lightON.118.jpg',
#  'lightON.396.jpg',
#  'lightOFF.845.jpg',
#  'lightOFF.707.jpg',
#  'lightOFF.69.jpg',
#  'lightON.603.jpg',
#  'lightOFF.843.jpg',
#  'lightOFF.544.jpg',
#  'lightOFF.399.jpg',
#  'lightON.520.jpg',
#  'lightON.518.jpg',
#  'lightON.362.jpg',
#  'lightON.129.jpg',
#  'lightON.904.jpg',
#  'lightON.707.jpg',
#  'lightON.831.jpg',
#  'lightOFF.657.jpg',
#  'lightON.724.jpg',
#  'lightOFF.124.jpg',
#  'lightOFF.806.jpg',
#  'lightON.788.jpg',
#  'lightOFF.2.jpg',
#  'lightOFF.787.jpg',
#  'lightOFF.280.jpg',
#  'lightOFF.634.jpg',
#  'lightON.57.jpg',
#  'lightON.51.jpg',
#  'lightON.619.jpg',
#  'lightON.262.jpg',
#  'lightON.327.jpg',
#  'lightON.451.jpg',
#  'lightON.435.jpg',
#  'lightON.114.jpg',
#  'lightON.705.jpg',
#  'lightOFF.868.jpg',
#  'lightON.423.jpg',
#  'lightON.688.jpg',
#  'lightOFF.577.jpg',
#  'lightOFF.560.jpg',
#  'lightON.869.jpg',
#  'lightON.697.jpg',
#  'lightON.884.jpg',
#  'lightON.346.jpg',
#  'lightON.213.jpg',
#  'lightOFF.496.jpg',
#  'lightOFF.420.jpg',
#  'lightOFF.738.jpg',
#  'lightON.577.jpg',
#  'lightON.635.jpg',
#  'lightON.250.jpg',
#  'lightON.254.jpg',
#  'lightOFF.70.jpg',
#  'lightON.71.jpg',
#  'lightON.881.jpg',
#  'lightON.475.jpg',
#  'lightON.888.jpg',
#  'lightOFF.199.jpg',
#  'lightOFF.751.jpg',
#  'lightON.825.jpg',
#  'lightOFF.348.jpg',
#  'lightOFF.63.jpg',
#  'lightON.567.jpg',
#  'lightOFF.516.jpg',
#  'lightOFF.784.jpg',
#  'lightOFF.663.jpg',
#  'lightOFF.295.jpg',
#  'lightON.670.jpg',
#  'lightON.553.jpg',
#  'lightOFF.196.jpg',
#  'lightOFF.301.jpg',
#  'lightOFF.517.jpg',
#  'lightOFF.418.jpg',
#  'lightON.196.jpg',
#  'lightON.906.jpg',
#  'lightOFF.45.jpg',
#  'lightOFF.154.jpg',
#  'lightON.437.jpg',
#  'lightOFF.484.jpg',
#  'lightON.694.jpg',
#  'lightOFF.758.jpg',
#  'lightON.728.jpg',
#  'lightON.860.jpg',
#  'lightOFF.570.jpg',
#  'lightON.495.jpg',
#  'lightOFF.762.jpg',
#  'lightON.561.jpg',
#  'lightON.511.jpg',
#  'lightOFF.38.jpg',
#  'lightOFF.258.jpg',
#  'lightON.388.jpg',
#  'lightOFF.717.jpg',
#  'lightOFF.439.jpg',
#  'lightOFF.177.jpg',
#  'lightOFF.239.jpg',
#  'lightOFF.156.jpg',
#  'lightON.666.jpg',
#  'lightON.407.jpg',
#  'lightOFF.441.jpg',
#  'lightON.74.jpg',
#  'lightOFF.611.jpg',
#  'lightON.273.jpg',
#  'lightOFF.122.jpg',
#  'lightON.203.jpg',
#  'lightOFF.170.jpg',
#  'lightOFF.375.jpg',
#  'lightOFF.623.jpg',
#  'lightON.217.jpg',
#  'lightON.535.jpg',
#  'lightOFF.837.jpg',
#  'lightON.506.jpg',
#  'lightON.696.jpg',
#  'lightOFF.492.jpg',
#  'lightON.296.jpg',
#  'lightOFF.374.jpg',
#  'lightOFF.232.jpg',
#  'lightON.391.jpg',
#  'lightON.684.jpg',
#  'lightON.310.jpg',
#  'lightON.226.jpg',
#  'lightOFF.94.jpg',
#  'lightON.863.jpg',
#  'lightOFF.755.jpg',
#  'lightON.132.jpg',
#  'lightOFF.706.jpg',
#  'lightOFF.502.jpg',
#  'lightOFF.43.jpg',
#  'lightOFF.649.jpg',
#  'lightOFF.314.jpg',
#  'lightOFF.140.jpg',
#  'lightON.189.jpg',
#  'lightON.719.jpg',
#  'lightON.445.jpg',
#  'lightOFF.709.jpg',
#  'lightOFF.253.jpg',
#  'lightON.285.jpg',
#  'lightON.314.jpg',
#  'lightON.711.jpg',
#  'lightON.16.jpg',
#  'lightON.578.jpg',
#  'lightON.510.jpg',
#  'lightOFF.488.jpg',
#  'lightON.471.jpg',
#  'lightON.289.jpg',
#  'lightON.142.jpg',
#  'lightOFF.257.jpg',
#  'lightON.339.jpg',
#  'lightOFF.624.jpg',
#  'lightON.402.jpg',
#  'lightOFF.737.jpg',
#  'lightOFF.854.jpg',
#  'lightON.760.jpg',
#  'lightOFF.219.jpg',
#  'lightOFF.631.jpg',
#  'lightOFF.799.jpg',
#  'lightOFF.342.jpg',
#  'lightON.847.jpg',
#  'lightON.740.jpg',
#  'lightOFF.781.jpg',
#  'lightON.748.jpg',
#  'lightON.202.jpg',
#  'lightOFF.472.jpg',
#  'lightOFF.728.jpg',
#  'lightOFF.741.jpg',
#  'lightOFF.673.jpg',
#  'lightON.167.jpg',
#  'lightON.422.jpg',
#  'lightON.677.jpg',
#  'lightOFF.146.jpg',
#  'lightON.238.jpg',
#  'lightON.204.jpg',
#  'lightOFF.168.jpg',
#  'lightON.93.jpg',
#  'lightOFF.255.jpg',
#  'lightOFF.846.jpg',
#  'lightOFF.71.jpg',
#  'lightON.540.jpg',
#  'lightON.483.jpg',
#  'lightON.693.jpg',
#  'lightOFF.343.jpg',
#  'lightON.725.jpg',
#  'lightOFF.768.jpg',
#  'lightOFF.269.jpg',
#  'lightON.656.jpg',
#  'lightOFF.820.jpg',
#  'lightOFF.772.jpg',
#  'lightOFF.214.jpg',
#  'lightOFF.642.jpg',
#  'lightON.512.jpg',
#  'lightOFF.777.jpg',
#  'lightON.613.jpg',
#  'lightON.211.jpg',
#  'lightOFF.515.jpg',
#  'lightOFF.792.jpg',
#  'lightON.380.jpg',
#  'lightON.59.jpg',
#  'lightON.543.jpg',
#  'lightOFF.322.jpg',
#  'lightOFF.725.jpg',
#  'lightOFF.817.jpg',
#  'lightOFF.855.jpg',
#  'lightOFF.35.jpg',
#  'lightON.641.jpg',
#  'lightOFF.702.jpg',
#  'lightON.531.jpg',
#  'lightOFF.59.jpg',
#  'lightON.631.jpg',
#  'lightOFF.540.jpg',
#  'lightOFF.711.jpg',
#  'lightOFF.696.jpg',
#  'lightOFF.874.jpg',
#  'lightOFF.580.jpg',
#  'lightON.630.jpg',
#  'lightOFF.403.jpg',
#  'lightON.131.jpg',
#  'lightOFF.355.jpg',
#  'lightON.525.jpg',
#  'lightON.150.jpg',
#  'lightOFF.209.jpg',
#  'lightOFF.272.jpg',
#  'lightOFF.835.jpg',
#  'lightON.86.jpg',
#  'lightON.320.jpg',
#  'lightON.163.jpg',
#  'lightON.479.jpg',
#  'lightOFF.90.jpg',
#  'lightOFF.568.jpg',
#  'lightON.903.jpg',
#  'lightOFF.54.jpg',
#  'lightOFF.687.jpg',
#  'lightON.7.jpg',
#  'lightOFF.62.jpg',
#  'lightON.290.jpg',
#  'lightON.158.jpg',
#  'lightON.353.jpg',
#  'lightOFF.130.jpg',
#  'lightON.517.jpg',
#  'lightOFF.453.jpg',
#  'lightOFF.430.jpg',
#  'lightOFF.458.jpg',
#  'lightOFF.126.jpg',
#  'lightOFF.326.jpg',
#  'lightOFF.571.jpg',
#  'lightON.248.jpg',
#  'lightON.376.jpg',
#  'lightON.616.jpg',
#  'lightON.761.jpg',
#  'lightON.883.jpg',
#  'lightOFF.353.jpg',
#  'lightON.331.jpg',
#  'lightON.33.jpg',
#  'lightON.31.jpg',
#  'lightOFF.230.jpg',
#  'lightON.280.jpg',
#  'lightON.352.jpg',
#  'lightOFF.542.jpg',
#  'lightOFF.369.jpg',
#  'lightOFF.440.jpg',
#  'lightOFF.128.jpg',
#  'lightON.145.jpg',
#  'lightOFF.259.jpg',
#  'lightOFF.703.jpg',
#  'lightON.480.jpg',
#  'lightOFF.522.jpg',
#  'lightOFF.796.jpg',
#  'lightOFF.150.jpg',
#  'lightOFF.388.jpg',
#  'lightOFF.667.jpg',
#  'lightON.472.jpg',
#  'lightOFF.134.jpg',
#  'lightON.144.jpg',
#  'lightON.403.jpg',
#  'lightOFF.153.jpg',
#  'lightOFF.47.jpg',
#  'lightON.436.jpg',
#  'lightOFF.310.jpg',
#  'lightON.184.jpg',
#  'lightOFF.320.jpg',
#  'lightOFF.189.jpg',
#  'lightON.13.jpg',
#  'lightON.746.jpg',
#  'lightON.834.jpg',
#  'lightOFF.291.jpg',
#  'lightOFF.207.jpg',
#  'lightON.667.jpg',
#  'lightON.147.jpg',
#  'lightON.408.jpg',
#  'lightON.844.jpg',
#  'lightON.439.jpg',
#  'lightOFF.752.jpg',
#  'lightON.318.jpg',
#  'lightON.676.jpg',
#  'lightON.447.jpg',
#  'lightOFF.296.jpg',
#  'lightOFF.483.jpg',
#  'lightOFF.878.jpg',
#  'lightON.416.jpg',
#  'lightOFF.34.jpg',
#  'lightON.117.jpg',
#  'lightON.231.jpg',
#  'lightON.269.jpg',
#  'lightON.122.jpg',
#  'lightOFF.594.jpg',
#  'lightOFF.60.jpg',
#  'lightOFF.609.jpg',
#  'lightOFF.335.jpg',
#  'lightON.22.jpg',
#  'lightOFF.174.jpg',
#  'lightON.546.jpg',
#  'lightON.271.jpg',
#  'lightOFF.193.jpg',
#  'lightOFF.764.jpg',
#  'lightON.255.jpg',
#  'lightON.576.jpg',
#  'lightON.105.jpg',
#  'lightOFF.541.jpg',
#  'lightOFF.566.jpg',
#  'lightON.193.jpg',
#  'lightOFF.836.jpg',
#  'lightON.246.jpg',
#  'lightOFF.632.jpg',
#  'lightOFF.630.jpg',
#  'lightOFF.337.jpg',
#  'lightOFF.231.jpg',
#  'lightOFF.664.jpg',
#  'lightON.611.jpg',
#  'lightOFF.129.jpg',
#  'lightOFF.181.jpg',
#  'lightON.901.jpg',
#  'lightON.367.jpg',
#  'lightOFF.731.jpg',
#  'lightON.664.jpg',
#  'lightON.715.jpg',
#  'lightON.753.jpg',
#  'lightON.319.jpg',
#  'lightOFF.733.jpg',
#  'lightOFF.435.jpg',
#  'lightON.17.jpg',
#  'lightON.306.jpg',
#  'lightON.441.jpg',
#  'lightON.272.jpg',
#  'lightOFF.123.jpg',
#  'lightOFF.216.jpg',
#  'lightON.690.jpg',
#  'lightOFF.616.jpg',
#  'lightOFF.790.jpg',
#  'lightOFF.645.jpg',
#  'lightOFF.805.jpg',
#  'lightOFF.840.jpg',
#  'lightOFF.700.jpg',
#  'lightOFF.639.jpg',
#  'lightOFF.600.jpg',
#  'lightON.363.jpg',
#  'lightON.595.jpg',
#  'lightON.816.jpg',
#  'lightON.542.jpg',
#  'lightOFF.387.jpg',
#  'lightOFF.478.jpg',
#  'lightON.526.jpg',
#  'lightOFF.856.jpg',
#  'lightOFF.133.jpg',
#  'lightOFF.327.jpg',
#  'lightON.197.jpg',
#  'lightON.782.jpg',
#  'lightOFF.686.jpg',
#  'lightON.134.jpg',
#  'lightON.228.jpg',
#  'lightOFF.36.jpg',
#  'lightON.292.jpg',
#  'lightOFF.304.jpg',
#  'lightON.245.jpg',
#  'lightON.90.jpg',
#  'lightOFF.445.jpg',
#  'lightON.252.jpg',
#  'lightOFF.561.jpg',
#  'lightOFF.490.jpg',
#  'lightON.5.jpg',
#  'lightON.398.jpg',
#  'lightOFF.273.jpg',
#  'lightON.281.jpg',
#  'lightOFF.573.jpg',
#  'lightON.78.jpg',
#  'lightON.448.jpg',
#  'lightOFF.178.jpg',
#  'lightOFF.669.jpg',
#  'lightON.328.jpg',
#  'lightON.43.jpg',
#  'lightOFF.218.jpg',
#  'lightON.714.jpg',
#  'lightOFF.620.jpg',
#  'lightOFF.31.jpg',
#  'lightON.414.jpg',
#  'lightOFF.465.jpg',
#  'lightOFF.393.jpg',
#  'lightON.424.jpg',
#  'lightON.216.jpg',
#  'lightOFF.50.jpg',
#  'lightOFF.659.jpg',
#  'lightOFF.677.jpg',
#  'lightOFF.114.jpg',
#  'lightOFF.173.jpg',
#  'lightON.839.jpg',
#  'lightOFF.789.jpg',
#  'lightOFF.354.jpg',
#  'lightOFF.206.jpg',
#  'lightOFF.603.jpg',
#  'lightON.508.jpg',
#  'lightON.138.jpg',
#  'lightOFF.306.jpg',
#  'lightOFF.808.jpg',
#  'lightON.750.jpg',
#  'lightON.295.jpg',
#  'lightON.14.jpg',
#  'lightOFF.710.jpg',
#  'lightOFF.454.jpg',
#  'lightOFF.708.jpg',
#  'lightON.751.jpg',
#  'lightON.154.jpg',
#  'lightOFF.818.jpg',
#  'lightON.749.jpg',
#  'lightOFF.830.jpg',
#  'lightOFF.734.jpg',
#  'lightON.485.jpg',
#  'lightOFF.605.jpg',
#  'lightOFF.67.jpg',
#  'lightOFF.718.jpg',
#  'lightOFF.376.jpg',
#  'lightOFF.532.jpg',
#  'lightON.874.jpg',
#  'lightOFF.235.jpg',
#  'lightON.139.jpg',
#  'lightON.258.jpg',
#  'lightOFF.169.jpg',
#  'lightOFF.344.jpg',
#  'lightON.266.jpg',
#  'lightON.481.jpg',
#  'lightOFF.646.jpg',
#  'lightON.305.jpg',
#  'lightON.259.jpg',
#  'lightON.770.jpg',
#  'lightON.152.jpg',
#  'lightON.430.jpg',
#  'lightOFF.73.jpg',
#  'lightOFF.318.jpg',
#  'lightOFF.237.jpg',
#  'lightOFF.407.jpg',
#  'lightON.330.jpg',
#  'lightON.299.jpg',
#  'lightOFF.670.jpg',
#  'lightOFF.562.jpg',
#  'lightOFF.65.jpg',
#  'lightOFF.724.jpg',
#  'lightON.6.jpg',
#  'lightOFF.319.jpg',
#  'lightOFF.378.jpg',
#  'lightON.905.jpg',
#  'lightON.878.jpg',
#  'lightOFF.876.jpg',
#  'lightON.624.jpg',
#  'lightOFF.119.jpg',
#  'lightON.166.jpg',
#  'lightON.48.jpg',
#  'lightOFF.284.jpg',
#  'lightON.706.jpg',
#  'lightOFF.400.jpg',
#  'lightON.230.jpg',
#  'lightON.61.jpg',
#  'lightON.812.jpg',
#  'lightON.70.jpg',
#  'lightOFF.104.jpg',
#  'lightOFF.395.jpg',
#  'lightON.356.jpg',
#  'lightON.727.jpg',
#  'lightON.19.jpg',
#  'lightON.265.jpg',
#  'lightOFF.745.jpg',
#  'lightOFF.873.jpg',
#  'lightOFF.775.jpg',
#  'lightON.44.jpg',
#  'lightON.466.jpg',
#  'lightOFF.394.jpg',
#  'lightOFF.293.jpg',
#  'lightON.745.jpg',
#  'lightON.151.jpg',
#  'lightOFF.328.jpg',
#  'lightON.501.jpg',
#  'lightON.598.jpg',
#  'lightON.762.jpg',
#  'lightON.209.jpg',
#  'lightON.411.jpg',
#  'lightOFF.135.jpg',
#  'lightOFF.791.jpg',
#  'lightON.297.jpg',
#  'lightON.80.jpg',
#  'lightON.208.jpg',
#  'lightOFF.744.jpg',
#  'lightOFF.615.jpg',
#  'lightOFF.305.jpg',
#  'lightOFF.21.jpg',
#  'lightON.645.jpg',
#  'lightOFF.143.jpg',
#  'lightON.552.jpg',
#  'lightOFF.644.jpg',
#  'lightOFF.149.jpg',
#  'lightOFF.16.jpg',
#  'lightOFF.425.jpg',
#  'lightOFF.109.jpg',
#  'lightOFF.770.jpg',
#  'lightOFF.362.jpg',
#  'lightON.902.jpg',
#  'lightOFF.78.jpg',
#  'lightOFF.584.jpg',
#  'lightOFF.730.jpg',
#  'lightON.900.jpg',
#  'lightON.9.jpg',
#  'lightOFF.757.jpg',
#  'lightOFF.12.jpg',
#  'lightOFF.463.jpg',
#  'lightON.159.jpg',
#  'lightON.796.jpg',
#  'lightON.337.jpg',
#  'lightOFF.779.jpg',
#  'lightOFF.469.jpg',
#  'lightON.349.jpg',
#  'lightOFF.487.jpg',
#  'lightOFF.539.jpg',
#  'lightOFF.471.jpg',
#  'lightON.473.jpg',
#  'lightOFF.747.jpg',
#  'lightOFF.228.jpg',
#  'lightON.497.jpg',
#  'lightOFF.497.jpg',
#  'lightON.589.jpg',
#  'lightON.175.jpg',
#  'lightOFF.596.jpg',
#  'lightOFF.113.jpg',
#  'lightOFF.161.jpg',
#  'lightOFF.824.jpg',
#  'lightOFF.754.jpg',
#  'lightON.298.jpg',
#  'lightOFF.778.jpg',
#  'lightOFF.386.jpg',
#  'lightON.557.jpg',
#  'lightOFF.797.jpg',
#  'lightOFF.557.jpg',
#  'lightOFF.628.jpg',
#  'lightON.404.jpg',
#  'lightON.734.jpg',
#  'lightOFF.175.jpg',
#  'lightON.427.jpg',
#  'lightOFF.815.jpg',
#  'lightOFF.503.jpg',
#  'lightOFF.137.jpg',
#  'lightON.768.jpg',
#  'lightON.534.jpg',
#  'lightON.618.jpg',
#  'lightON.792.jpg',
#  'lightOFF.610.jpg',
#  'lightON.604.jpg',
#  'lightON.623.jpg',
#  'lightON.848.jpg',
#  'lightOFF.832.jpg',
#  'lightOFF.224.jpg',
#  'lightOFF.25.jpg',
#  'lightON.674.jpg',
#  'lightOFF.498.jpg',
#  'lightON.658.jpg',
#  'lightON.513.jpg',
#  'lightOFF.691.jpg',
#  'lightOFF.290.jpg',
#  'lightON.736.jpg',
#  'lightOFF.28.jpg',
#  'lightON.261.jpg',
#  'lightOFF.223.jpg',
#  'lightOFF.286.jpg',
#  'lightON.291.jpg',
#  'lightOFF.410.jpg',
#  'lightON.452.jpg',
#  'lightON.400.jpg',
#  'lightOFF.451.jpg',
#  'lightOFF.331.jpg',
#  'lightON.643.jpg',
#  'lightON.699.jpg',
#  'lightOFF.582.jpg',
#  'lightOFF.508.jpg',
#  'lightON.732.jpg',
#  'lightON.773.jpg',
#  'lightOFF.438.jpg',
#  'lightON.183.jpg',
#  'lightOFF.166.jpg',
#  'lightON.673.jpg',
#  'lightOFF.397.jpg',
#  'lightON.40.jpg',
#  'lightOFF.205.jpg',
#  'lightON.803.jpg',
#  'lightOFF.531.jpg',
#  'lightOFF.714.jpg',
#  'lightON.307.jpg',
#  'lightON.607.jpg',
#  'lightON.563.jpg',
#  'lightON.133.jpg',
#  'lightOFF.636.jpg',
#  'lightOFF.187.jpg',
#  'lightOFF.658.jpg',
#  'lightON.835.jpg',
#  'lightOFF.823.jpg',
#  'lightOFF.774.jpg',
#  'lightON.809.jpg',
#  'lightOFF.455.jpg',
#  'lightOFF.866.jpg',
#  'lightON.862.jpg',
#  'lightOFF.141.jpg',
#  'lightOFF.338.jpg',
#  'lightOFF.552.jpg',
#  'lightOFF.881.jpg',
#  'lightON.274.jpg',
#  'lightON.821.jpg',
#  'lightON.164.jpg',
#  'lightOFF.652.jpg',
#  'lightON.747.jpg',
#  'lightON.360.jpg',
#  'lightOFF.283.jpg',
#  'lightON.823.jpg',
#  'lightOFF.64.jpg',
#  'lightOFF.37.jpg',
#  'lightOFF.827.jpg',
#  'lightON.347.jpg',
#  'lightOFF.157.jpg',
#  'lightOFF.643.jpg',
#  'lightOFF.859.jpg',
#  'lightOFF.512.jpg',
#  'lightOFF.125.jpg',
#  'lightOFF.795.jpg',
#  'lightON.802.jpg',
#  'lightON.66.jpg',
#  'lightOFF.499.jpg',
#  'lightOFF.75.jpg',
#  'lightON.798.jpg',
#  'lightON.240.jpg',
#  'lightON.507.jpg',
#  'lightON.532.jpg',
#  'lightOFF.358.jpg',
#  'lightON.153.jpg',
#  'lightON.647.jpg',
#  'lightON.849.jpg',
#  'lightON.463.jpg',
#  'lightOFF.506.jpg',
#  'lightON.366.jpg',
#  'lightOFF.528.jpg',
#  'lightON.287.jpg',
#  'lightOFF.547.jpg',
#  'lightOFF.411.jpg',
#  'lightON.644.jpg',
#  'lightON.702.jpg',
#  'lightON.776.jpg',
#  'lightON.115.jpg',
#  'lightOFF.423.jpg',
#  'lightON.370.jpg',
#  'lightON.188.jpg',
#  'lightON.20.jpg',
#  'lightON.897.jpg',
#  'lightOFF.29.jpg',
#  'lightOFF.227.jpg',
#  'lightON.345.jpg',
#  'lightOFF.298.jpg',
#  'lightON.791.jpg',
#  'lightOFF.312.jpg',
#  'lightON.21.jpg',
#  'lightON.504.jpg',
#  'lightOFF.665.jpg',
#  'lightOFF.117.jpg',
#  'lightOFF.277.jpg',
#  'lightON.655.jpg',
#  'lightON.875.jpg',
#  'lightOFF.753.jpg',
#  'lightOFF.159.jpg',
#  'lightON.277.jpg',
#  'lightON.413.jpg',
#  'lightOFF.186.jpg',
#  'lightON.146.jpg',
#  'lightOFF.563.jpg',
#  'lightOFF.262.jpg',
#  'lightON.26.jpg',
#  'lightOFF.844.jpg',
#  ...]

# %%
light_names = os.listdir(path)
on_off_labels = [each.split('.')[0] for each in light_names]
on_off_file_id =[each.split('.')[1] for each in light_names]

# %%
len(light_names)
# Out:
# 1789

# %%
# import random
# import matplotlib.pyplot as plt
# import matplotlib.image as mpimg
# %matplotlib inline

sample = random.choice(light_names)
image = mpimg.imread(path + sample)
plt.imshow(image)
plt.show()

# %%
sample = random.choice(light_names)
image = mpimg.imread(path+ sample)
image.shape
# Out:
# (1280, 720, 3)

# %%
from skimage.transform import resize
resized = resize(image, (195, 195, 3)) #300, 300 크기로 변경

fig, axes = plt.subplots(1, 2, figsize =(8, 4))
ax = axes.ravel()

ax[0].imshow(image, cmap = plt.cm.gray)
ax[0].set_title("light_on_off_image")
ax[1].imshow(resized, cmap =plt.cm.gray)
ax[1].set_title("resized_light_on_off_check_image")

fig.tight_layout()
plt.show()

# %%
from tqdm.notebook import tqdm
from skimage.color import rgb2gray
import numpy as np

images = []
bar_total = tqdm(light_names)
for file in bar_total:
    image = mpimg.imread(path+file)
    images.append(resize(image, (195, 195, 3)))

images = np.array(images)
# Out:
#   0%|          | 0/1789 [00:00<?, ?it/s]

# %%
images.shape, light_names[:5]
# Out:
# ((1789, 195, 195, 3),
#  ['lightOFF.240.jpg',
#   'lightOFF.530.jpg',
#   'lightON.852.jpg',
#   'lightOFF.80.jpg',
#   'lightON.34.jpg'])

# %%
images[:3]
# Out:
# array([[[[0.62461688, 0.59324433, 0.5854012 ],
#          [0.62297154, 0.59159899, 0.58375585],
#          [0.60891871, 0.57754616, 0.56970302],
#          ...,
#          [0.6739178 , 0.65413027, 0.64059657],
#          [0.61964818, 0.59986065, 0.58632695],
#          [0.5942296 , 0.57444207, 0.56090837]],
#
#         [[0.62104748, 0.58967493, 0.58183179],
#          [0.61815379, 0.58678125, 0.57893811],
#          [0.57758782, 0.54621527, 0.53837213],
#          ...,
#          [0.58278015, 0.56051637, 0.5574559 ],
#          [0.57505217, 0.55278838, 0.54972791],
#          [0.57717157, 0.5549078 , 0.55184733]],
#
#         [[0.62229123, 0.59091868, 0.58307554],
#          [0.6233262 , 0.59195365, 0.58411052],
#          [0.61401388, 0.58264133, 0.5747982 ],
#          ...,
#          [0.57345414, 0.55866665, 0.56057826],
#          [0.57374677, 0.55895917, 0.5608708 ],
#          [0.57508246, 0.56029502, 0.56220661]],
#
#         ...,
#
#         [[0.58708319, 0.54511095, 0.52218095],
#          [0.57794097, 0.54072349, 0.53584299],
#          [0.54845889, 0.52439629, 0.53587197],
#          ...,
#          [0.71160969, 0.677766  , 0.66392213],
#          [0.71160969, 0.67776597, 0.66392222],
#          [0.71160969, 0.67776601, 0.6639221 ]],
#
#         [[0.5896666 , 0.54881347, 0.52141092],
#          [0.57811756, 0.54025571, 0.53946314],
#          [0.54750918, 0.52313855, 0.53994801],
#          ...,
#          [0.70985926, 0.67841357, 0.67041733],
#          [0.70985926, 0.67841357, 0.67041734],
#          [0.70985926, 0.67841357, 0.67041733]],
#
#         [[0.59435902, 0.55353517, 0.52601557],
#          [0.58064652, 0.54276995, 0.54210378],
#          [0.55122814, 0.5268522 , 0.54382892],
#          ...,
#          [0.70980392, 0.67843137, 0.67058824],
#          [0.70980392, 0.67843137, 0.67058824],
#          [0.70980392, 0.67843137, 0.67058824]]],
#
#
#        [[[0.51566791, 0.51174634, 0.50389112],
#          [0.51559282, 0.51167125, 0.50097936],
#          [0.51191711, 0.50799554, 0.49230584],
#          ...,
#          [0.46216619, 0.44255817, 0.42243602],
#          [0.4652957 , 0.44568768, 0.42556552],
#          [0.45777374, 0.43816572, 0.41804357]],
#
#         [[0.51402765, 0.50993849, 0.50202757],
#          [0.51398374, 0.50989458, 0.49918741],
#          [0.51191313, 0.50782396, 0.49219018],
#          ...,
#          [0.46482177, 0.4449969 , 0.43273564],
#          [0.46150456, 0.44167969, 0.42941843],
#          [0.45682827, 0.4370034 , 0.42474214]],
#
#         [[0.51584905, 0.50535298, 0.49531302],
#          [0.51938492, 0.50888886, 0.49759745],
#          [0.51835963, 0.50786357, 0.49436728],
#          ...,
#          [0.44994999, 0.42936916, 0.42051849],
#          [0.4444241 , 0.42384328, 0.4149926 ],
#          [0.4427205 , 0.42213968, 0.413289  ]],
#
#         ...,
#
#         [[0.3795812 , 0.34320979, 0.23135264],
#          [0.38302997, 0.34610448, 0.23398652],
#          [0.39361853, 0.3542577 , 0.25501384],
#          ...,
#          [0.49543267, 0.43903432, 0.43298077],
#          [0.49197312, 0.43087676, 0.42621823],
#          [0.48866837, 0.42451485, 0.42110219]],
#
#         [[0.40484521, 0.3660787 , 0.26166507],
#          [0.40400752, 0.36323496, 0.26912386],
#          [0.39902796, 0.35602156, 0.27649555],
#          ...,
#          [0.47510389, 0.44508303, 0.43310398],
#          [0.47085596, 0.44072851, 0.42877855],
#          [0.46852454, 0.43829894, 0.42637837]],
#
#         [[0.40833846, 0.36740311, 0.27432414],
#          [0.38571144, 0.34286973, 0.25964915],
#          [0.37442903, 0.33032944, 0.2594655 ],
#          ...,
#          [0.47754702, 0.4620093 , 0.44419812],
#          [0.47242229, 0.45688458, 0.43907339],
#          [0.47214649, 0.45660878, 0.4387976 ]]],
#
#
#        [[[0.50967359, 0.5057339 , 0.49005366],
#          [0.51277039, 0.50457569, 0.49031379],
#          [0.52067972, 0.50503138, 0.49322532],
#          ...,
#          [0.40685641, 0.39108059, 0.39508829],
#          [0.39829679, 0.3876049 , 0.39152647],
#          [0.39159472, 0.38373951, 0.38766107]],
#
#         [[0.50782877, 0.5035686 , 0.48798243],
#          [0.51300394, 0.50450933, 0.49038405],
#          [0.51973188, 0.50396807, 0.49234728],
#          ...,
#          [0.40051358, 0.38485345, 0.38885848],
#          [0.40271762, 0.39206632, 0.39598789],
#          [0.3955807 , 0.38772565, 0.39164722]],
#
#         [[0.51749053, 0.50425454, 0.49104273],
#          [0.52033491, 0.50416576, 0.49397401],
#          [0.52039295, 0.50033671, 0.49606752],
#          ...,
#          [0.40125299, 0.38992762, 0.39387697],
#          [0.40764838, 0.39854846, 0.40247003],
#          [0.40262673, 0.39477826, 0.39869983]],
#
#         ...,
#
#         [[0.70038225, 0.65925438, 0.62827366],
#          [0.70032055, 0.65919272, 0.62821184],
#          [0.70178078, 0.66065293, 0.62967216],
#          ...,
#          [0.29954798, 0.26644536, 0.26379243],
#          [0.29862026, 0.26551764, 0.26286471],
#          [0.29333811, 0.26023549, 0.25758256]],
#
#         [[0.69348215, 0.65389343, 0.61793734],
#          [0.6970494 , 0.65746068, 0.62150458],
#          [0.70143824, 0.66184951, 0.62589342],
#          ...,
#          [0.31201154, 0.27677329, 0.28052726],
#          [0.31622604, 0.28098779, 0.28474176],
#          [0.31825027, 0.28301201, 0.28676599]],
#
#         [[0.67839195, 0.63591035, 0.61038231],
#          [0.67722532, 0.63474372, 0.60921568],
#          [0.68404849, 0.64156689, 0.61603884],
#          ...,
#          [0.34559025, 0.31029614, 0.31421771],
#          [0.34947149, 0.31417738, 0.31809894],
#          [0.35351425, 0.31822013, 0.3221417 ]]]])

# %%
from sklearn.preprocessing import LabelEncoder

encoder = LabelEncoder()
encoder.fit(on_off_labels)
light_on_off_labels_encoded = encoder.transform(on_off_labels)
light_on_off_labels_encoded[:3], encoder.classes_
# Out:
# (array([0, 0, 1]), array(['lightOFF', 'lightON'], dtype='<U8'))

# %%
# 1.12 데이터 나누고

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train , y_test =\
                train_test_split(images, light_on_off_labels_encoded, test_size =0.2,
                                 random_state = 13, stratify  = light_on_off_labels_encoded)
X_train.shape, X_test.shape
# Out:
# ((1431, 195, 195, 3), (358, 195, 195, 3))

# %%
samples = random.choices(population = range(0, 244), k =8 )

plt.figure(figsize =(14,12))
for idx, n in enumerate(samples):
    plt.subplot(2, 4, idx+1)
    plt.imshow(X_train[n], cmap ='Greys',interpolation = 'nearest')
    plt.title(y_train[n])

plt.tight_layout()
plt.show()

# %%
from tensorflow.keras import layers, models

model = models.Sequential([layers.Conv2D(32,(3,3), activation ='relu', input_shape=(195,195,3)),
                           layers.MaxPooling2D(pool_size=(2,2), strides =(2,2)),
                           layers.Dropout(0.25),
                           
                           layers.Conv2D(64,(3,3), activation='relu',padding ='same'),
                           layers.MaxPooling2D(pool_size=(2,2)),
                           layers.Dropout(0.25),

                           layers.Conv2D(64,(3,3), activation='relu',padding ='same'),
                           layers.MaxPooling2D(pool_size=(2,2)),
                           layers.Dropout(0.25),
                           
                           layers.Flatten(),
                           layers.Dense(512, activation ='relu'),
                           layers.Dropout(0.25),
                           layers.Dense(2, activation ='softmax')])



model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 193, 193, 32)      896
#
#  max_pooling2d (MaxPooling2  (None, 96, 96, 32)        0
#  D)
#
#  dropout (Dropout)           (None, 96, 96, 32)        0
#
#  conv2d_1 (Conv2D)           (None, 96, 96, 64)        18496
#
#  max_pooling2d_1 (MaxPoolin  (None, 48, 48, 64)        0
#  g2D)
#
#  dropout_1 (Dropout)         (None, 48, 48, 64)        0
#
#  conv2d_2 (Conv2D)           (None, 48, 48, 64)        36928
#
#  max_pooling2d_2 (MaxPoolin  (None, 24, 24, 64)        0
#  g2D)
#
#  dropout_2 (Dropout)         (None, 24, 24, 64)        0
#
#  flatten (Flatten)           (None, 36864)             0
#
#  dense (Dense)               (None, 512)               18874880
#
#  dropout_3 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 2)                 1026
#
# =================================================================
# Total params: 18932226 (72.22 MB)
# Trainable params: 18932226 (72.22 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# 2023-11-17 15:56:04.640057: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-17 15:56:04.640351: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-17 15:56:04.640581: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-17 15:56:05.291797: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-17 15:56:05.292045: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-17 15:56:05.292163: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-11-17 15:56:05.292254: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1886] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 4370 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 2060, pci bus id: 0000:01:00.0, compute capability: 7.5

# %%
model.compile(optimizer='adam', loss = 'sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
import time

start_time = time.time()
hist = model.fit(X_train.reshape(1431, 195, 195, 3), y_train,
                 epochs = 15, verbose =1, #처음 5번
                 validation_data = (X_test.reshape(358, 195, 195, 3), y_test))
print("fit time :", time.time() - start_time)
# Out:
# 2023-11-17 15:56:09.945554: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 652965300 exceeds 10% of free system memory.
# 2023-11-17 15:56:10.300357: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 652965300 exceeds 10% of free system memory.
# Epoch 1/15
# 2023-11-17 15:56:11.184770: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:961] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape insequential/dropout/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 2023-11-17 15:56:12.681578: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:442] Loaded cuDNN version 8800
# 2023-11-17 15:56:15.620763: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7fd3749aaa80 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-11-17 15:56:15.620787: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 2060, Compute Capability 7.5
# 2023-11-17 15:56:15.626878: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-11-17 15:56:15.707004: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 45/45 [==============================] - 11s 100ms/step - loss: 1.0221 - accuracy: 0.6073 - val_loss: 0.5447 - val_accuracy: 0.7486
# Epoch 2/15
# 45/45 [==============================] - 3s 68ms/step - loss: 0.3479 - accuracy: 0.8728 - val_loss: 0.2385 - val_accuracy: 0.9218
# Epoch 3/15
# 45/45 [==============================] - 3s 68ms/step - loss: 0.1361 - accuracy: 0.9532 - val_loss: 0.0806 - val_accuracy: 0.9637
# Epoch 4/15
# 45/45 [==============================] - 3s 68ms/step - loss: 0.0293 - accuracy: 0.9937 - val_loss: 0.3214 - val_accuracy: 0.8827
# Epoch 5/15
# 45/45 [==============================] - 3s 68ms/step - loss: 0.0244 - accuracy: 0.9923 - val_loss: 0.0086 - val_accuracy: 1.0000
# Epoch 6/15
# 45/45 [==============================] - 3s 68ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.0156 - val_accuracy: 1.0000
# Epoch 7/15
# 45/45 [==============================] - 3s 68ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0188 - val_accuracy: 0.9944
# Epoch 8/15
# 45/45 [==============================] - 3s 69ms/step - loss: 7.4130e-04 - accuracy: 1.0000 - val_loss: 0.0052 - val_accuracy: 1.0000
# Epoch 9/15
# 45/45 [==============================] - 3s 69ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0017 - val_accuracy: 1.0000
# Epoch 10/15
# 45/45 [==============================] - 3s 68ms/step - loss: 0.0277 - accuracy: 0.9895 - val_loss: 8.4085e-04 - val_accuracy: 1.0000
# Epoch 11/15
# 45/45 [==============================] - 3s 70ms/step - loss: 0.0046 - accuracy: 0.9986 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 12/15
# 45/45 [==============================] - 3s 69ms/step - loss: 0.0030 - accuracy: 0.9986 - val_loss: 0.0014 - val_accuracy: 1.0000
# Epoch 13/15
# 45/45 [==============================] - 3s 69ms/step - loss: 0.0013 - accuracy: 0.9993 - val_loss: 0.0125 - val_accuracy: 1.0000
# Epoch 14/15
# 45/45 [==============================] - 3s 69ms/step - loss: 5.6851e-04 - accuracy: 1.0000 - val_loss: 3.2571e-04 - val_accuracy: 1.0000
# Epoch 15/15
# 45/45 [==============================] - 3s 70ms/step - loss: 6.3585e-05 - accuracy: 1.0000 - val_loss: 1.8107e-04 - val_accuracy: 1.0000
# fit time : 55.20419192314148

# %%
score = model.evaluate(X_test, y_test)
print('Test loss :', score[0])
print('Test accuracy :', score[1])
# Out:
# 12/12 [==============================] - 0s 13ms/step - loss: 1.8107e-04 - accuracy: 1.0000
# Test loss : 0.0001810747926356271
# Test accuracy : 1.0

# %%
plot_target = ['loss', 'val_loss', 'accuracy', 'val_accuracy']
plt.figure(figsize=(12,8))

for each in plot_target:
    plt.plot(hist.history[each], label = each)
plt.legend()
plt.grid()
plt.show()

# %%
import matplotlib
print(matplotlib.__version__)
# Out:
# 3.8.0

# %%
# !pip install --upgrade matplotlib
# Out:
# Requirement already satisfied: matplotlib in /home/kang/venv/deep_running/lib/python3.10/site-packages (3.8.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/kang/venv/deep_running/lib/python3.10/site-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /home/kang/venv/deep_running/lib/python3.10/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in /home/kang/venv/deep_running/lib/python3.10/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: numpy<2,>=1.21 in /home/kang/venv/deep_running/lib/python3.10/site-packages (from matplotlib) (1.26.1)
# Requirement already satisfied: pillow>=8 in /home/kang/venv/deep_running/lib/python3.10/site-packages (from matplotlib) (10.0.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/kang/venv/deep_running/lib/python3.10/site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: fonttools>=4.22.0 in /home/kang/venv/deep_running/lib/python3.10/site-packages (from matplotlib) (4.43.1)
# Requirement already satisfied: contourpy>=1.0.1 in /home/kang/venv/deep_running/lib/python3.10/site-packages (from matplotlib) (1.1.1)
# Requirement already satisfied: packaging>=20.0 in /home/kang/venv/deep_running/lib/python3.10/site-packages (from matplotlib) (23.2)
# Requirement already satisfied: six>=1.5 in /home/kang/venv/deep_running/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
import numpy as np
predicted_result = model.predict(X_test)
predicted_labels = np.argmax(predicted_result, axis=1)
predicted_labels[:10]
# Out:
# 12/12 [==============================] - 0s 12ms/step
# array([0, 1, 1, 1, 0, 0, 1, 1, 0, 1])

# %%
wrong_result =[]

for n in range(0, len(y_test)):
    if predicted_labels[n] != y_test[n]:
        wrong_result.append(n)
len(wrong_result)
# Out:
# 0

# %%
plt.figure(figsize =(14,12))

for idx, n in enumerate(wrong_result):
    plt.subplot(1, 4, idx +1)
    plt.imshow(X_test[n], cmap='Greys', interpolation='nearest')
    plt.title('Label :' + str(y_test[n])+ ' Predict :' + str(predicted_labels[n]))
    plt.axis('off')

plt.show()
